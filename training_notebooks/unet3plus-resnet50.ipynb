# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import tensorflow as tf
import tensorflow.keras.layers as L
from tensorflow.keras.applications import ResNet50

def conv_block(x, num_filters, act=True):
    x = L.Conv2D(num_filters, kernel_size=3, padding="same")(x)

    if act == True:
        x = L.BatchNormalization()(x)
        x = L.Activation("relu")(x)

    return x

def encoder_block(x, num_filters):
    x = conv_block(x, num_filters)
    x = conv_block(x, num_filters)

    p = L.MaxPool2D((2, 2))(x)
    return x, p

def unet3plus(input_shape, num_classes=1):
    """ Inputs """
    inputs = L.Input(input_shape, name="input_layer")

    """ Pre-trained ResNet50 Model """
    encoder = ResNet50(include_top=False, weights="imagenet", input_tensor=inputs)

    """ Encoder """
    e1 = encoder.get_layer("input_layer").output
    e2 = encoder.get_layer("conv1_relu").output
    e3 = encoder.get_layer("conv2_block3_out").output
    e4 = encoder.get_layer("conv3_block4_out").output

    """ Bridge """
    e5 = encoder.get_layer("conv4_block6_out").output

    """ Decoder 4 """
    e1_d4 = L.MaxPool2D((8, 8))(e1)
    e1_d4 = conv_block(e1_d4, 64)

    e2_d4 = L.MaxPool2D((4, 4))(e2)
    e2_d4 = conv_block(e2_d4, 64)

    e3_d4 = L.MaxPool2D((2, 2))(e3)
    e3_d4 = conv_block(e3_d4, 64)

    e4_d4 = conv_block(e4, 64)

    e5_d4 = L.UpSampling2D((2, 2), interpolation="bilinear")(e5)
    e5_d4 = conv_block(e5_d4, 64)

    d4 = L.Concatenate()([e1_d4, e2_d4, e3_d4, e4_d4, e5_d4])
    d4 = conv_block(d4, 64*5)

    """ Decoder 3 """
    e1_d3 = L.MaxPool2D((4, 4))(e1)
    e1_d3 = conv_block(e1_d3, 64)

    e2_d3 = L.MaxPool2D((2, 2))(e2)
    e2_d3 = conv_block(e2_d3, 64)

    e3_d3 = conv_block(e3, 64)

    d4_d3 = L.UpSampling2D((2, 2), interpolation="bilinear")(d4)
    d4_d3 = conv_block(d4_d3, 64)

    e5_d3 = L.UpSampling2D((4, 4), interpolation="bilinear")(e5)
    e5_d3 = conv_block(e5_d3, 64)

    d3 = L.Concatenate()([e1_d3, e2_d3, e3_d3, d4_d3, e5_d3])
    d3 = conv_block(d3, 64*5)

    """ Decoder 2 """
    e1_d2 = L.MaxPool2D((2, 2))(e1)
    e1_d2 = conv_block(e1_d2, 64)

    e2_d2 = conv_block(e2, 64)

    d3_d2 = L.UpSampling2D((2, 2), interpolation="bilinear")(d3)
    d3_d2 = conv_block(d3_d2, 64)

    d4_d2 = L.UpSampling2D((4, 4), interpolation="bilinear")(d4)
    d4_d2 = conv_block(d4_d2, 64)

    e5_d2 = L.UpSampling2D((8, 8), interpolation="bilinear")(e5)
    e5_d2 = conv_block(e5_d2, 64)

    d2 = L.Concatenate()([e1_d2, e2_d2, d3_d2, d4_d2, e5_d2])
    d2 = conv_block(d2, 64*5)

    """ Decoder 1 """
    e1_d1 = conv_block(e1, 64)

    d2_d1 = L.UpSampling2D((2, 2), interpolation="bilinear")(d2)
    d2_d1 = conv_block(d2_d1, 64)

    d3_d1 = L.UpSampling2D((4, 4), interpolation="bilinear")(d3)
    d3_d1 = conv_block(d3_d1, 64)

    d4_d1 = L.UpSampling2D((8, 8), interpolation="bilinear")(d4)
    d4_d1 = conv_block(d4_d1, 64)

    e5_d1 = L.UpSampling2D((16, 16), interpolation="bilinear")(e5)
    e5_d1 = conv_block(e5_d1, 64)

    d1 = L.Concatenate()([e1_d1, d2_d1, d3_d1, d4_d1, e5_d1])
    d1 = conv_block(d1, 64*5)

    """ Output """
    y1 = L.Conv2D(num_classes, kernel_size=3, padding="same")(d1)
    y1 = L.Activation("sigmoid")(y1)
    outputs = [y1]

    model = tf.keras.Model(inputs, outputs)
    return model


if __name__ == "__main__":
    input_shape = (256, 256, 3)
    model = unet3plus(input_shape)
    model.summary()
# Out:
# 2024-05-21 07:46:40.754867: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-21 07:46:40.754993: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-21 07:46:40.888034: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Model: "functional_1"

# %%
import numpy as np
import tensorflow as tf

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import keras
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Adam, SGD
from sklearn.model_selection import train_test_split
# from model import unet3plus
# from metrics import dice_loss, dice_coef

IMG_H = 256
IMG_W = 256

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def load_dataset(path, split=0.1):
    """ Loading the images and masks """
    X = sorted(glob(os.path.join(path, "images", "*")))
    Y = sorted(glob(os.path.join(path, "masks", "*")))

    """ Spliting the data into training and testing """
    split_size = int(len(X) * split)

    train_x, valid_x = train_test_split(X, test_size=split_size, random_state=42)
    train_y, valid_y = train_test_split(Y, test_size=split_size, random_state=42)

    train_x, test_x = train_test_split(train_x, test_size=split_size, random_state=42)
    train_y, test_y = train_test_split(train_y, test_size=split_size, random_state=42)

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

def read_image(path):
    path = path.decode()
    image = cv2.imread(path, cv2.IMREAD_COLOR)
    image = cv2.resize(image, (IMG_W, IMG_H))
    image = image / 255.0
    image = image.astype(np.float32)
    return image

def read_mask(path):
    path = path.decode()
    mask = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    mask = cv2.resize(mask, (IMG_W, IMG_H))
    mask = mask / 255.0
    mask = mask.astype(np.float32)
    mask = np.expand_dims(mask, axis=-1)
    return mask

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([IMG_H, IMG_W, 3])
    y.set_shape([IMG_H, IMG_W, 1])
    return x, y

def tf_dataset(X, Y, batch=2):
    ds = tf.data.Dataset.from_tensor_slices((X, Y))
    ds = ds.map(tf_parse).batch(batch).prefetch(10)
    return ds

if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("files")

    """ Hyperparameters """
    batch_size = 4
    lr = 1e-4
    num_epochs = 100
    model_path = os.path.join("files", "model.keras")
    csv_path = os.path.join("files", "log.csv")

    """ Dataset """
    dataset_path = "/kaggle/input/kvasir-seg/Kvasir-SEG"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_dataset(dataset_path)

    print(f"Train: \t{len(train_x)} - {len(train_y)}")
    print(f"Valid: \t{len(valid_x)} - {len(valid_y)}")
    print(f"Test: \t{len(test_x)} - {len(test_y)}")

    train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
    valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)

    """ Model """
    model = unet3plus((IMG_H, IMG_W, 3))
    model.compile(loss=dice_loss, optimizer=Adam(lr), metrics=[dice_coef, keras.metrics.MeanIoU(num_classes=2)])
    # model.summary()

    callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-10, verbose=1),
        CSVLogger(csv_path),
        EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=False)
    ]

    model.fit(
        train_dataset,
        epochs=num_epochs,
        validation_data=valid_dataset,
        callbacks=callbacks
    )
# Out:
# Train: 	800 - 800
# Valid: 	100 - 100
# Test: 	100 - 100
# Epoch 1/100
# 2024-05-21 07:48:15.058795: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 3.24577, expected 2.80959
# 2024-05-21 07:48:15.058858: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 179: 3.17396, expected 2.73778
# 2024-05-21 07:48:15.059564: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65536: 3.15611, expected 2.41005
# 2024-05-21 07:48:15.059602: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65537: 3.84262, expected 3.09657
# 2024-05-21 07:48:15.059617: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65538: 4.59187, expected 3.84581
# 2024-05-21 07:48:15.059628: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65539: 5.43123, expected 4.68518
# 2024-05-21 07:48:15.059640: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65540: 5.1009, expected 4.35484
# 2024-05-21 07:48:15.059657: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65541: 5.74889, expected 5.00283
# 2024-05-21 07:48:15.059673: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65542: 5.35053, expected 4.60448
# 2024-05-21 07:48:15.059689: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65543: 5.29655, expected 4.5505
# 2024-05-21 07:48:15.067288: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[4,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,3,256,256]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-21 07:48:15.067323: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-21 07:48:15.067336: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-21 07:48:15.067346: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-21 07:48:15.067355: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-21 07:48:15.067377: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-05-21 07:48:15.345356: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 3.24577, expected 2.80959
# 2024-05-21 07:48:15.345433: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 179: 3.17396, expected 2.73778
# 2024-05-21 07:48:15.345921: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65536: 3.15611, expected 2.41005
# 2024-05-21 07:48:15.345989: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65537: 3.84262, expected 3.09657
# 2024-05-21 07:48:15.346015: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65538: 4.59187, expected 3.84581
# 2024-05-21 07:48:15.346029: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65539: 5.43123, expected 4.68518
# 2024-05-21 07:48:15.346066: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65540: 5.1009, expected 4.35484
# 2024-05-21 07:48:15.346084: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65541: 5.74889, expected 5.00283
# 2024-05-21 07:48:15.346105: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65542: 5.35053, expected 4.60448
# 2024-05-21 07:48:15.346150: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65543: 5.29655, expected 4.5505
# 2024-05-21 07:48:15.353863: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[4,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,3,256,256]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-21 07:48:15.353895: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-21 07:48:15.353910: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-21 07:48:15.353922: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-21 07:48:15.353931: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-21 07:48:15.353950: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-05-21 07:48:15.480764: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 4.30713, expected 3.49091
# 2024-05-21 07:48:15.480824: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 6.64842, expected 5.8322
# 2024-05-21 07:48:15.480838: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 5.76946, expected 4.95324
# 2024-05-21 07:48:15.480850: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 5.54472, expected 4.72851
# 2024-05-21 07:48:15.480863: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 4.93375, expected 4.11754
# 2024-05-21 07:48:15.480873: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 4.64631, expected 3.8301
# 2024-05-21 07:48:15.480883: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 4.40703, expected 3.59081
# 2024-05-21 07:48:15.480893: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 4.13418, expected 3.31796
# 2024-05-21 07:48:15.480903: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 3.86354, expected 3.04733
# 2024-05-21 07:48:15.480913: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 4.12421, expected 3.308
# 2024-05-21 07:48:15.482741: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[4,64,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,3,128,128]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-21 07:48:15.482780: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-21 07:48:15.482793: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-21 07:48:15.482809: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-21 07:48:15.482820: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-21 07:48:15.482841: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-05-21 07:48:15.553782: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 4.30713, expected 3.49091
# 2024-05-21 07:48:15.553831: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 6.64842, expected 5.8322
# 2024-05-21 07:48:15.553846: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 5.76946, expected 4.95324
# 2024-05-21 07:48:15.553863: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 5.54472, expected 4.72851
# 2024-05-21 07:48:15.553878: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 4.93375, expected 4.11754
# 2024-05-21 07:48:15.553888: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 4.64631, expected 3.8301
# 2024-05-21 07:48:15.553899: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 4.40703, expected 3.59081
# 2024-05-21 07:48:15.553910: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 4.13418, expected 3.31796
# 2024-05-21 07:48:15.553921: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 3.86354, expected 3.04733
# 2024-05-21 07:48:15.553932: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 4.12421, expected 3.308
# 2024-05-21 07:48:15.556275: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[4,64,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,3,128,128]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-21 07:48:15.556312: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-21 07:48:15.556326: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-21 07:48:15.556336: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-21 07:48:15.556346: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-21 07:48:15.556366: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1716277781.673040     100 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - dice_coef: 0.6608 - loss: 0.3392 - mean_io_u: 0.5525
# Epoch 1: val_loss improved from inf to 0.98778, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 257s 601ms/step - dice_coef: 0.6612 - loss: 0.3388 - mean_io_u: 0.5525 - val_dice_coef: 0.0122 - val_loss: 0.9878 - val_mean_io_u: 0.4220 - learning_rate: 1.0000e-04
# Epoch 2/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - dice_coef: 0.8436 - loss: 0.1564 - mean_io_u: 0.6492
# Epoch 2: val_loss did not improve from 0.98778
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 112s 560ms/step - dice_coef: 0.8437 - loss: 0.1563 - mean_io_u: 0.6490 - val_dice_coef: 6.9497e-04 - val_loss: 0.9993 - val_mean_io_u: 0.4220 - learning_rate: 1.0000e-04
# Epoch 3/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - dice_coef: 0.8906 - loss: 0.1094 - mean_io_u: 0.6865
# Epoch 3: val_loss improved from 0.98778 to 0.85198, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 113s 567ms/step - dice_coef: 0.8906 - loss: 0.1094 - mean_io_u: 0.6864 - val_dice_coef: 0.1480 - val_loss: 0.8520 - val_mean_io_u: 0.4220 - learning_rate: 1.0000e-04
# Epoch 4/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - dice_coef: 0.9208 - loss: 0.0792 - mean_io_u: 0.7164
# Epoch 4: val_loss improved from 0.85198 to 0.32825, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 113s 567ms/step - dice_coef: 0.9209 - loss: 0.0791 - mean_io_u: 0.7163 - val_dice_coef: 0.6717 - val_loss: 0.3283 - val_mean_io_u: 0.5619 - learning_rate: 1.0000e-04
# Epoch 5/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - dice_coef: 0.9347 - loss: 0.0653 - mean_io_u: 0.7454
# Epoch 5: val_loss improved from 0.32825 to 0.20284, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 113s 567ms/step - dice_coef: 0.9347 - loss: 0.0653 - mean_io_u: 0.7453 - val_dice_coef: 0.7972 - val_loss: 0.2028 - val_mean_io_u: 0.6403 - learning_rate: 1.0000e-04
# Epoch 6/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - dice_coef: 0.9428 - loss: 0.0572 - mean_io_u: 0.7748
# Epoch 6: val_loss improved from 0.20284 to 0.17378, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 114s 568ms/step - dice_coef: 0.9427 - loss: 0.0573 - mean_io_u: 0.7747 - val_dice_coef: 0.8262 - val_loss: 0.1738 - val_mean_io_u: 0.6833 - learning_rate: 1.0000e-04
# Epoch 7/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - dice_coef: 0.9478 - loss: 0.0522 - mean_io_u: 0.8173
# Epoch 7: val_loss did not improve from 0.17378
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 112s 560ms/step - dice_coef: 0.9478 - loss: 0.0522 - mean_io_u: 0.8172 - val_dice_coef: 0.8069 - val_loss: 0.1931 - val_mean_io_u: 0.6288 - learning_rate: 1.0000e-04
# Epoch 8/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - dice_coef: 0.9577 - loss: 0.0423 - mean_io_u: 0.8410
# Epoch 8: val_loss improved from 0.17378 to 0.13897, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 113s 567ms/step - dice_coef: 0.9577 - loss: 0.0423 - mean_io_u: 0.8409 - val_dice_coef: 0.8610 - val_loss: 0.1390 - val_mean_io_u: 0.7139 - learning_rate: 1.0000e-04
# Epoch 9/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - dice_coef: 0.9645 - loss: 0.0355 - mean_io_u: 0.8738
# Epoch 9: val_loss did not improve from 0.13897
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 112s 560ms/step - dice_coef: 0.9645 - loss: 0.0355 - mean_io_u: 0.8737 - val_dice_coef: 0.8307 - val_loss: 0.1693 - val_mean_io_u: 0.6160 - learning_rate: 1.0000e-04
# Epoch 10/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - dice_coef: 0.9686 - loss: 0.0314 - mean_io_u: 0.8674
# Epoch 10: val_loss improved from 0.13897 to 0.13803, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 113s 567ms/step - dice_coef: 0.9686 - loss: 0.0314 - mean_io_u: 0.8674 - val_dice_coef: 0.8620 - val_loss: 0.1380 - val_mean_io_u: 0.7045 - learning_rate: 1.0000e-04
# Epoch 11/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - dice_coef: 0.9703 - loss: 0.0297 - mean_io_u: 0.8739
# Epoch 11: val_loss improved from 0.13803 to 0.13626, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 113s 567ms/step - dice_coef: 0.9703 - loss: 0.0297 - mean_io_u: 0.8738 - val_dice_coef: 0.8637 - val_loss: 0.1363 - val_mean_io_u: 0.7551 - learning_rate: 1.0000e-04
# Epoch 12/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - dice_coef: 0.9691 - loss: 0.0309 - mean_io_u: 0.8922
# Epoch 12: val_loss did not improve from 0.13626
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 112s 560ms/step - dice_coef: 0.9691 - loss: 0.0309 - mean_io_u: 0.8921 - val_dice_coef: 0.6883 - val_loss: 0.3117 - val_mean_io_u: 0.6221 - learning_rate: 1.0000e-04
# Epoch 13/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - dice_coef: 0.9484 - loss: 0.0516 - mean_io_u: 0.8444
# Epoch 13: val_loss did not improve from 0.13626
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 112s 560ms/step - dice_coef: 0.9484 - loss: 0.0516 - mean_io_u: 0.8444 - val_dice_coef: 0.8053 - val_loss: 0.1947 - val_mean_io_u: 0.6987 - learning_rate: 1.0000e-04
# Epoch 14/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - dice_coef: 0.9530 - loss: 0.0470 - mean_io_u: 0.8363
# Epoch 14: val_loss did not improve from 0.13626
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 112s 560ms/step - dice_coef: 0.9530 - loss: 0.0470 - mean_io_u: 0.8363 - val_dice_coef: 0.8482 - val_loss: 0.1518 - val_mean_io_u: 0.6961 - learning_rate: 1.0000e-04
# Epoch 15/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - dice_coef: 0.9408 - loss: 0.0592 - mean_io_u: 0.8688
# Epoch 15: val_loss did not improve from 0.13626
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 112s 560ms/step - dice_coef: 0.9408 - loss: 0.0592 - mean_io_u: 0.8687 - val_dice_coef: 0.8313 - val_loss: 0.1687 - val_mean_io_u: 0.7441 - learning_rate: 1.0000e-04
# Epoch 16/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - dice_coef: 0.9516 - loss: 0.0484 - mean_io_u: 0.8566
# Epoch 16: val_loss did not improve from 0.13626
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 112s 560ms/step - dice_coef: 0.9516 - loss: 0.0484 - mean_io_u: 0.8565 - val_dice_coef: 0.7618 - val_loss: 0.2382 - val_mean_io_u: 0.6316 - learning_rate: 1.0000e-04
# Epoch 17/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - dice_coef: 0.9665 - loss: 0.0335 - mean_io_u: 0.8931
# Epoch 17: val_loss did not improve from 0.13626
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 112s 560ms/step - dice_coef: 0.9665 - loss: 0.0335 - mean_io_u: 0.8931 - val_dice_coef: 0.8567 - val_loss: 0.1433 - val_mean_io_u: 0.7659 - learning_rate: 1.0000e-05
# Epoch 18/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - dice_coef: 0.9709 - loss: 0.0291 - mean_io_u: 0.9064
# Epoch 18: val_loss did not improve from 0.13626
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 112s 560ms/step - dice_coef: 0.9710 - loss: 0.0290 - mean_io_u: 0.9064 - val_dice_coef: 0.8607 - val_loss: 0.1393 - val_mean_io_u: 0.7714 - learning_rate: 1.0000e-05
# Epoch 19/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - dice_coef: 0.9730 - loss: 0.0270 - mean_io_u: 0.9118
# Epoch 19: val_loss did not improve from 0.13626
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 112s 560ms/step - dice_coef: 0.9730 - loss: 0.0270 - mean_io_u: 0.9117 - val_dice_coef: 0.8623 - val_loss: 0.1377 - val_mean_io_u: 0.7746 - learning_rate: 1.0000e-05
# Epoch 20/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - dice_coef: 0.9744 - loss: 0.0256 - mean_io_u: 0.9152
# Epoch 20: val_loss did not improve from 0.13626
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 112s 560ms/step - dice_coef: 0.9744 - loss: 0.0256 - mean_io_u: 0.9151 - val_dice_coef: 0.8623 - val_loss: 0.1377 - val_mean_io_u: 0.7764 - learning_rate: 1.0000e-05
# Epoch 21/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - dice_coef: 0.9754 - loss: 0.0246 - mean_io_u: 0.9175
# Epoch 21: val_loss did not improve from 0.13626
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 112s 560ms/step - dice_coef: 0.9754 - loss: 0.0246 - mean_io_u: 0.9174 - val_dice_coef: 0.8625 - val_loss: 0.1375 - val_mean_io_u: 0.7773 - learning_rate: 1.0000e-05

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import numpy as np
import cv2
import imageio
from glob import glob
from tqdm import tqdm
import tensorflow as tf
# from train import create_dir, load_dataset
# from metrics import dice_loss, dice_coef

IMG_H = 256
IMG_W = 256

if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir(f"results")

    """ Load the model """
    model_path = os.path.join("files", "model.keras")
    model = tf.keras.models.load_model(model_path, custom_objects={"dice_loss": dice_loss, "dice_coef": dice_coef})

    """ Dataset """
    dataset_path = "/kaggle/input/kvasir-seg/Kvasir-SEG"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_dataset(dataset_path)

    print(f"Train: \t{len(train_x)} - {len(train_y)}")
    print(f"Valid: \t{len(valid_x)} - {len(valid_y)}")
    print(f"Test: \t{len(test_x)} - {len(test_y)}")

    """ Prediction """
    for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
        """ Extracting the name """
        name = x.split("/")[-1].split(".")[0]

        """ Reading the image """
        image = cv2.imread(x, cv2.IMREAD_COLOR)
        image = cv2.resize(image, (IMG_W, IMG_H))
        x = image / 255.0
        x = np.expand_dims(x, axis=0)

        """ Read Mask """
        mask = cv2.imread(y, cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, (IMG_W, IMG_H))
        mask = mask / 255.0
        mask = np.expand_dims(mask, axis=-1)
        mask = np.concatenate([mask, mask, mask], axis=-1)

        """ Prediction """
        pred = model.predict(x, verbose=0)[0]
        pred = np.concatenate([pred, pred, pred], axis=-1)
        # pred = (pred > 0.5).astype(np.int32)

        """ Save final mask """
        line = np.ones((IMG_H, 10, 3)) * 255
        cat_images = np.concatenate([image, line, mask*255, line, pred*255], axis=1)
        save_image_path = os.path.join("results",  f"{name}.jpg")
        cv2.imwrite(save_image_path, cat_images)
# Out:
# Train: 	800 - 800
# Valid: 	100 - 100
# Test: 	100 - 100
#   0%|          | 0/100 [00:00<?, ?it/s]2024-05-21 08:39:14.539375: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 2.86272, expected 2.0465
# 2024-05-21 08:39:14.539448: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 4.04967, expected 3.23345
# 2024-05-21 08:39:14.539459: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 4.4326, expected 3.61638
# 2024-05-21 08:39:14.539467: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 5.46868, expected 4.65247
# 2024-05-21 08:39:14.539475: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 5.37814, expected 4.56193
# 2024-05-21 08:39:14.539485: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 5.18374, expected 4.36753
# 2024-05-21 08:39:14.539494: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 5.54872, expected 4.7325
# 2024-05-21 08:39:14.539502: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 5.78654, expected 4.97032
# 2024-05-21 08:39:14.539510: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 4.0901, expected 3.27388
# 2024-05-21 08:39:14.539518: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 5.11265, expected 4.29643
# 2024-05-21 08:39:14.539536: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[1,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,3,256,256]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-21 08:39:14.539545: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-21 08:39:14.539553: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-21 08:39:14.539561: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-21 08:39:14.539569: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-21 08:39:14.539580: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-05-21 08:39:14.580612: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 2.86272, expected 2.0465
# 2024-05-21 08:39:14.580669: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 4.04967, expected 3.23345
# 2024-05-21 08:39:14.580678: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 4.4326, expected 3.61638
# 2024-05-21 08:39:14.580687: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 5.46868, expected 4.65247
# 2024-05-21 08:39:14.580694: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 5.37814, expected 4.56193
# 2024-05-21 08:39:14.580702: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 5.18374, expected 4.36753
# 2024-05-21 08:39:14.580710: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 5.54872, expected 4.7325
# 2024-05-21 08:39:14.580717: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 5.78654, expected 4.97032
# 2024-05-21 08:39:14.580726: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 4.0901, expected 3.27388
# 2024-05-21 08:39:14.580738: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 5.11265, expected 4.29643
# 2024-05-21 08:39:14.580769: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[1,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,3,256,256]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-21 08:39:14.580793: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-21 08:39:14.580804: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-21 08:39:14.580816: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-21 08:39:14.580827: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-21 08:39:14.580841: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-05-21 08:39:14.621695: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32768: 3.66788, expected 2.82077
# 2024-05-21 08:39:14.621750: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32769: 5.27059, expected 4.42348
# 2024-05-21 08:39:14.621760: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32770: 5.00058, expected 4.15347
# 2024-05-21 08:39:14.621768: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32771: 4.72297, expected 3.87586
# 2024-05-21 08:39:14.621775: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32772: 4.5861, expected 3.73899
# 2024-05-21 08:39:14.621783: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32773: 4.17555, expected 3.32844
# 2024-05-21 08:39:14.621791: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32774: 3.43326, expected 2.58615
# 2024-05-21 08:39:14.621798: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32775: 3.61347, expected 2.76636
# 2024-05-21 08:39:14.621806: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32776: 2.90622, expected 2.05911
# 2024-05-21 08:39:14.621814: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32777: 3.1097, expected 2.26259
# 2024-05-21 08:39:14.621832: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[1,64,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,3,128,128]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-21 08:39:14.621846: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-21 08:39:14.621859: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-21 08:39:14.621870: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-21 08:39:14.621879: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-21 08:39:14.621896: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-05-21 08:39:14.646193: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32768: 3.66788, expected 2.82077
# 2024-05-21 08:39:14.646247: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32769: 5.27059, expected 4.42348
# 2024-05-21 08:39:14.646256: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32770: 5.00058, expected 4.15347
# 2024-05-21 08:39:14.646265: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32771: 4.72297, expected 3.87586
# 2024-05-21 08:39:14.646272: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32772: 4.5861, expected 3.73899
# 2024-05-21 08:39:14.646280: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32773: 4.17555, expected 3.32844
# 2024-05-21 08:39:14.646288: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32774: 3.43326, expected 2.58615
# 2024-05-21 08:39:14.646295: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32775: 3.61347, expected 2.76636
# 2024-05-21 08:39:14.646304: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32776: 2.90622, expected 2.05911
# 2024-05-21 08:39:14.646314: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32777: 3.1097, expected 2.26259
# 2024-05-21 08:39:14.646343: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[1,64,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,3,128,128]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-21 08:39:14.646360: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-21 08:39:14.646371: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-21 08:39:14.646382: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-21 08:39:14.646404: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-21 08:39:14.646433: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 100%|██████████| 100/100 [00:27<00:00,  3.65it/s]

# %%
test_dataset = tf_dataset(test_x, test_y, batch=batch_size)

# %%
results = model.evaluate(test_dataset)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 221ms/step - dice_coef: 0.8727 - loss: 0.1273 - mean_io_u: 0.7993

# %%
# !zip -r file.zip /kaggle/working
# Out:
#   adding: kaggle/working/ (stored 0%)
#   adding: kaggle/working/files/ (stored 0%)
#   adding: kaggle/working/files/model.keras (deflated 8%)
#   adding: kaggle/working/files/log.csv (deflated 55%)
#   adding: kaggle/working/results/ (stored 0%)
#   adding: kaggle/working/results/cju8cj10qsrau0871o2dr6ai1.jpg (deflated 11%)
#   adding: kaggle/working/results/cju2tjrog4jy30878pawyazqc.jpg (deflated 10%)
#   adding: kaggle/working/results/cju0sxqiclckk08551ycbwhno.jpg (deflated 11%)
#   adding: kaggle/working/results/cju6xlygpw7bs0818n691jsq4.jpg (deflated 8%)
#   adding: kaggle/working/results/cju8alhigqn2h0801zksudldd.jpg (deflated 7%)
#   adding: kaggle/working/results/cju8402x1kcy70801t6kz6bdi.jpg (deflated 7%)
#   adding: kaggle/working/results/cju6vqarjv7yo0987q4b1btk1.jpg (deflated 10%)
#   adding: kaggle/working/results/cju8bljw9rqk20801kr54akrl.jpg (deflated 8%)
#   adding: kaggle/working/results/cju2xf8e5y2wm08359vcgk09b.jpg (deflated 8%)
#   adding: kaggle/working/results/cju7cue9b232j0801qdzk1ykj.jpg (deflated 11%)
#   adding: kaggle/working/results/cju83h9ysjwe808716nt35oah.jpg (deflated 11%)
#   adding: kaggle/working/results/cju439oazm2fu0871ma0vvrft.jpg (deflated 7%)
#   adding: kaggle/working/results/cju326h4v1gxw08352px40p7r.jpg (deflated 7%)
#   adding: kaggle/working/results/cju15wdt3zla10801odjiw7sy.jpg (deflated 8%)
#   adding: kaggle/working/results/ck2bxskgxxzfv08386xkqtqdy.jpg (deflated 10%)
#   adding: kaggle/working/results/cju7et17a2vjk0755e743npl1.jpg (deflated 12%)
#   adding: kaggle/working/results/cju5xopi0md7q0871r1sjc1av.jpg (deflated 10%)
#   adding: kaggle/working/results/cju5ca9hcatkc0801jzwe7tfx.jpg (deflated 7%)
#   adding: kaggle/working/results/cju7db7lp2f400755tntd1ohf.jpg (deflated 9%)
#   adding: kaggle/working/results/cju88l66no10s0850rsda7ej1.jpg (deflated 7%)
#   adding: kaggle/working/results/cju7b3f5h1sm40755i572jden.jpg (deflated 9%)
#   adding: kaggle/working/results/cju1euuc65wm00799m4sjdnnn.jpg (deflated 11%)
#   adding: kaggle/working/results/cju1aqqv02qwz0878a5cyhr67.jpg (deflated 9%)
#   adding: kaggle/working/results/cju30525w04r10835ygp257sb.jpg (deflated 10%)
#   adding: kaggle/working/results/cju87z6o6nh73085045bzsx6o.jpg (deflated 11%)
#   adding: kaggle/working/results/cju3tp94kfstl08181awh6z49.jpg (deflated 6%)
#   adding: kaggle/working/results/cju83syhdk6gs0801rf1rekdl.jpg (deflated 9%)
#   adding: kaggle/working/results/cju2txjfzv60w098839dcimys.jpg (deflated 12%)
#   adding: kaggle/working/results/cju40sdwukv3k0755y99ug1k8.jpg (deflated 8%)
#   adding: kaggle/working/results/cju6wi3akvn8r0801px8eligc.jpg (deflated 7%)
#   adding: kaggle/working/results/cju41kd7yl4nm0850gil5qqwh.jpg (deflated 12%)
#   adding: kaggle/working/results/cju2wxv0hxs2f09884w48v8fi.jpg (deflated 9%)
#   adding: kaggle/working/results/cju42qet0lsq90871e50xbnuv.jpg (deflated 11%)
#   adding: kaggle/working/results/cju7d2q1k27nf08715zshsckt.jpg (deflated 11%)
#   adding: kaggle/working/results/cju3xiic0ilzp0850lusrb42j.jpg (deflated 15%)
#   adding: kaggle/working/results/cju41p90plcsx08018cnzpndc.jpg (deflated 9%)
#   adding: kaggle/working/results/cju1cfhyg48bb0799cl5pr2jh.jpg (deflated 8%)
#   adding: kaggle/working/results/cju8bm24yrrdp081829mbo8ic.jpg (deflated 10%)
#   adding: kaggle/working/results/cju42u5bjlvi10801dc13sskp.jpg (deflated 10%)
#   adding: kaggle/working/results/cju2wx0gh7fpz0878wwyd9ep8.jpg (deflated 10%)
#   adding: kaggle/working/results/cju87kbcen2av0987usezo8kn.jpg (deflated 9%)
#   adding: kaggle/working/results/cju0sr5ghl0nd08789uzf1raf.jpg (deflated 6%)
#   adding: kaggle/working/results/cju5huurrecm70801y680y13m.jpg (deflated 10%)
#   adding: kaggle/working/results/cju183od81ff608017ekzif89.jpg (deflated 8%)
#   adding: kaggle/working/results/cju2zrojo9kcd0878ld2epejq.jpg (deflated 12%)
#   adding: kaggle/working/results/cju1c8ffau5770835g0g343o8.jpg (deflated 8%)
#   adding: kaggle/working/results/cju2rn0hasxri0835nfy3buay.jpg (deflated 11%)
#   adding: kaggle/working/results/cju33za6l2qy70988jhrlp2ev.jpg (deflated 9%)
#   adding: kaggle/working/results/cju83wwn1k55e0850kw6i2d81.jpg (deflated 8%)
#   adding: kaggle/working/results/cju1hirfi7ekp0855q0vgm9qq.jpg (deflated 8%)
#   adding: kaggle/working/results/cju5fs6j6d8350801vglraq4u.jpg (deflated 8%)
#   adding: kaggle/working/results/cju1ejj7dvqfa0835ra184v5m.jpg (deflated 8%)
#   adding: kaggle/working/results/cju35fxqyzt5p0993vusm54qz.jpg (deflated 9%)
#   adding: kaggle/working/results/cju1fuoa4wmc50835qfd11sp9.jpg (deflated 10%)
#   adding: kaggle/working/results/cju3x2s11ibzi0817kk284k0j.jpg (deflated 9%)
#   adding: kaggle/working/results/cju7dizi82h2i0755doucgnt3.jpg (deflated 8%)
#   adding: kaggle/working/results/cju8418jhkf7d0818ga2v0xq0.jpg (deflated 9%)
#   adding: kaggle/working/results/cju7dvl5m2n4t0755hlnnjjet.jpg (deflated 10%)
#   adding: kaggle/working/results/cju84dsvaklpx098750hp83x4.jpg (deflated 6%)
#   adding: kaggle/working/results/cjyzkmjy8evns070165gf9dmq.jpg (deflated 11%)
#   adding: kaggle/working/results/cju1csmlc4ht10799b8ymmghg.jpg (deflated 10%)
#   adding: kaggle/working/results/cju5wkonqlrl409877y8zvnub.jpg (deflated 8%)
#   adding: kaggle/working/results/cju7efffp2ivf0817etg3jehl.jpg (deflated 7%)
#   adding: kaggle/working/results/cju0vtox5ain6099360pu62rp.jpg (deflated 13%)
#   adding: kaggle/working/results/cju5wuhm1lwm40987vugqn3vv.jpg (deflated 9%)
#   adding: kaggle/working/results/cju40m0rjkpw80871z6n6yg1u.jpg (deflated 7%)
#   adding: kaggle/working/results/cju1g4nsb6ngy0799l4ezm8ab.jpg (deflated 9%)
#   adding: kaggle/working/results/cju3u4lxmg59o0755rz42b9en.jpg (deflated 8%)
#   adding: kaggle/working/results/cju7ev2b12owa08500bpfpwyw.jpg (deflated 8%)
#   adding: kaggle/working/results/cju5wqonpm0e60801z88ewmy1.jpg (deflated 9%)
#   adding: kaggle/working/results/cju87tyddnnad0755bj0wxahe.jpg (deflated 7%)
#   adding: kaggle/working/results/cju43gfosm63n08714rpih8pe.jpg (deflated 8%)
#   adding: kaggle/working/results/cju89z6pqpqfx0817mfv8ixjc.jpg (deflated 13%)
#   adding: kaggle/working/results/cju17g6ykn1cs0993dww6qdi8.jpg (deflated 7%)
#   adding: kaggle/working/results/cju7bmi1v1pnj0987pa52jjok.jpg (deflated 9%)
#   adding: kaggle/working/results/cju85hguellg50818kwu3s8d1.jpg (deflated 7%)
#   adding: kaggle/working/results/cju1b75x63ddl0799sdp0i2j3.jpg (deflated 11%)
#   adding: kaggle/working/results/cju5h57xedz5h0755mjpc8694.jpg (deflated 5%)
#   adding: kaggle/working/results/cju30gxjq0djk0988jytm49rs.jpg (deflated 10%)
#   adding: kaggle/working/results/cju8cwy02t9eq08185qn12c02.jpg (deflated 10%)
#   adding: kaggle/working/results/cju5eq8c8ck690850vix98hv3.jpg (deflated 7%)
#   adding: kaggle/working/results/cju88cddensj00987788yotmg.jpg (deflated 11%)
#   adding: kaggle/working/results/cju88q6h6obpd0871ckmiabbo.jpg (deflated 9%)
#   adding: kaggle/working/results/cju34fojcctcf0799ebolbvkn.jpg (deflated 12%)
#   adding: kaggle/working/results/cju6vta3kvazg0817qbeppjtm.jpg (deflated 6%)
#   adding: kaggle/working/results/cju3v11mrgwwb0755u242ygye.jpg (deflated 11%)
#   adding: kaggle/working/results/cju2oq5570avm079959o20op1.jpg (deflated 10%)
#   adding: kaggle/working/results/cju87zv8lni0o0850hbbecbq6.jpg (deflated 9%)
#   adding: kaggle/working/results/cju2qozsk20cq0855ugrg3cri.jpg (deflated 7%)
#   adding: kaggle/working/results/cju85ia1slh220987y7c20sm2.jpg (deflated 9%)
#   adding: kaggle/working/results/cju33mirdc8mj0799k33wzoes.jpg (deflated 7%)
#   adding: kaggle/working/results/cju3uz4o6gr9z0850lhxyxvsj.jpg (deflated 9%)
#   adding: kaggle/working/results/cju8a84g0q76m0818hwiggkod.jpg (deflated 7%)
#   adding: kaggle/working/results/cju7dymur2od30755eg8yv2ht.jpg (deflated 10%)
#   adding: kaggle/working/results/cju7dsrtb2f8i085064kwugfk.jpg (deflated 11%)
#   adding: kaggle/working/results/cju1hyolc7aqu0878rrkfn1lr.jpg (deflated 10%)
#   adding: kaggle/working/results/cju302fqq9spc0878rrygyzzz.jpg (deflated 7%)
#   adding: kaggle/working/results/cju5u6wf0kh1t0755bg1ssixv.jpg (deflated 7%)
#   adding: kaggle/working/results/cju7agj961l2r0818z29iq8yn.jpg (deflated 13%)
#   adding: kaggle/working/results/cju5fb86jd1jp0755b1ukbhq5.jpg (deflated 9%)
#   adding: kaggle/working/.virtual_documents/ (stored 0%)
