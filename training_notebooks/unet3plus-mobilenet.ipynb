# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import tensorflow as tf
import tensorflow.keras.layers as L
from tensorflow.keras.applications import MobileNet

def conv_block(x, num_filters, act=True):
    x = L.Conv2D(num_filters, kernel_size=3, padding="same")(x)

    if act == True:
        x = L.BatchNormalization()(x)
        x = L.Activation("relu")(x)

    return x

def encoder_block(x, num_filters):
    x = conv_block(x, num_filters)
    x = conv_block(x, num_filters)

    p = L.MaxPool2D((2, 2))(x)
    return x, p

def unet3plus(input_shape, num_classes=1):
    """ Inputs """
    inputs = L.Input(input_shape, name="input_layer")

    """ Pre-trained MobileNet Model """
    encoder = MobileNet(include_top=False, weights="imagenet",
        input_tensor=inputs, alpha=1.0)

    """ Encoder """
    e1 = encoder.get_layer("input_layer").output
    e2 = encoder.get_layer("conv_pw_1_relu").output
    e3 = encoder.get_layer("conv_pw_3_relu").output
    e4 = encoder.get_layer("conv_pw_5_relu").output

    """ Bridge """
    e5 = encoder.get_layer("conv_pw_11_relu").output

    """ Decoder 4 """
    e1_d4 = L.MaxPool2D((8, 8))(e1)
    e1_d4 = conv_block(e1_d4, 64)

    e2_d4 = L.MaxPool2D((4, 4))(e2)
    e2_d4 = conv_block(e2_d4, 64)

    e3_d4 = L.MaxPool2D((2, 2))(e3)
    e3_d4 = conv_block(e3_d4, 64)

    e4_d4 = conv_block(e4, 64)

    e5_d4 = L.UpSampling2D((2, 2), interpolation="bilinear")(e5)
    e5_d4 = conv_block(e5_d4, 64)

    d4 = L.Concatenate()([e1_d4, e2_d4, e3_d4, e4_d4, e5_d4])
    d4 = conv_block(d4, 64*5)

    """ Decoder 3 """
    e1_d3 = L.MaxPool2D((4, 4))(e1)
    e1_d3 = conv_block(e1_d3, 64)

    e2_d3 = L.MaxPool2D((2, 2))(e2)
    e2_d3 = conv_block(e2_d3, 64)

    e3_d3 = conv_block(e3, 64)

    d4_d3 = L.UpSampling2D((2, 2), interpolation="bilinear")(d4)
    d4_d3 = conv_block(d4_d3, 64)

    e5_d3 = L.UpSampling2D((4, 4), interpolation="bilinear")(e5)
    e5_d3 = conv_block(e5_d3, 64)

    d3 = L.Concatenate()([e1_d3, e2_d3, e3_d3, d4_d3, e5_d3])
    d3 = conv_block(d3, 64*5)

    """ Decoder 2 """
    e1_d2 = L.MaxPool2D((2, 2))(e1)
    e1_d2 = conv_block(e1_d2, 64)

    e2_d2 = conv_block(e2, 64)

    d3_d2 = L.UpSampling2D((2, 2), interpolation="bilinear")(d3)
    d3_d2 = conv_block(d3_d2, 64)

    d4_d2 = L.UpSampling2D((4, 4), interpolation="bilinear")(d4)
    d4_d2 = conv_block(d4_d2, 64)

    e5_d2 = L.UpSampling2D((8, 8), interpolation="bilinear")(e5)
    e5_d2 = conv_block(e5_d2, 64)

    d2 = L.Concatenate()([e1_d2, e2_d2, d3_d2, d4_d2, e5_d2])
    d2 = conv_block(d2, 64*5)

    """ Decoder 1 """
    e1_d1 = conv_block(e1, 64)

    d2_d1 = L.UpSampling2D((2, 2), interpolation="bilinear")(d2)
    d2_d1 = conv_block(d2_d1, 64)

    d3_d1 = L.UpSampling2D((4, 4), interpolation="bilinear")(d3)
    d3_d1 = conv_block(d3_d1, 64)

    d4_d1 = L.UpSampling2D((8, 8), interpolation="bilinear")(d4)
    d4_d1 = conv_block(d4_d1, 64)

    e5_d1 = L.UpSampling2D((16, 16), interpolation="bilinear")(e5)
    e5_d1 = conv_block(e5_d1, 64)

    d1 = L.Concatenate()([e1_d1, d2_d1, d3_d1, d4_d1, e5_d1])
    d1 = conv_block(d1, 64*5)

    """ Output """
    y1 = L.Conv2D(num_classes, kernel_size=3, padding="same")(d1)
    y1 = L.Activation("sigmoid")(y1)
    outputs = [y1]

    model = tf.keras.Model(inputs, outputs)
    return model


if __name__ == "__main__":
    input_shape = (256, 256, 3)
    model = unet3plus(input_shape)
    model.summary()
# Out:
# 2024-05-23 11:02:27.941010: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-23 11:02:27.941130: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-23 11:02:28.075636: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /tmp/ipykernel_33/1789967653.py:29: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   encoder = MobileNet(include_top=False, weights="imagenet",
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1 (Conv2D)      │ (None, 128, 128,  │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_bn            │ (None, 128, 128,  │        128 │ conv1[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_relu (ReLU)   │ (None, 128, 128,  │          0 │ conv1_bn[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_1           │ (None, 128, 128,  │        288 │ conv1_relu[0][0]  │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_1_bn        │ (None, 128, 128,  │        128 │ conv_dw_1[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_1_relu      │ (None, 128, 128,  │          0 │ conv_dw_1_bn[0][… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_1 (Conv2D)  │ (None, 128, 128,  │      2,048 │ conv_dw_1_relu[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_1_bn        │ (None, 128, 128,  │        256 │ conv_pw_1[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_1_relu      │ (None, 128, 128,  │          0 │ conv_pw_1_bn[0][… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pad_2          │ (None, 129, 129,  │          0 │ conv_pw_1_relu[0… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_2           │ (None, 64, 64,    │        576 │ conv_pad_2[0][0]  │
# │ (DepthwiseConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_2_bn        │ (None, 64, 64,    │        256 │ conv_dw_2[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_2_relu      │ (None, 64, 64,    │          0 │ conv_dw_2_bn[0][… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_2 (Conv2D)  │ (None, 64, 64,    │      8,192 │ conv_dw_2_relu[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_2_bn        │ (None, 64, 64,    │        512 │ conv_pw_2[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_2_relu      │ (None, 64, 64,    │          0 │ conv_pw_2_bn[0][… │
# │ (ReLU)              │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_3           │ (None, 64, 64,    │      1,152 │ conv_pw_2_relu[0… │
# │ (DepthwiseConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_3_bn        │ (None, 64, 64,    │        512 │ conv_dw_3[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_3_relu      │ (None, 64, 64,    │          0 │ conv_dw_3_bn[0][… │
# │ (ReLU)              │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_3 (Conv2D)  │ (None, 64, 64,    │     16,384 │ conv_dw_3_relu[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_3_bn        │ (None, 64, 64,    │        512 │ conv_pw_3[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_3_relu      │ (None, 64, 64,    │          0 │ conv_pw_3_bn[0][… │
# │ (ReLU)              │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pad_4          │ (None, 65, 65,    │          0 │ conv_pw_3_relu[0… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_4           │ (None, 32, 32,    │      1,152 │ conv_pad_4[0][0]  │
# │ (DepthwiseConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_4_bn        │ (None, 32, 32,    │        512 │ conv_dw_4[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_4_relu      │ (None, 32, 32,    │          0 │ conv_dw_4_bn[0][… │
# │ (ReLU)              │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_4 (Conv2D)  │ (None, 32, 32,    │     32,768 │ conv_dw_4_relu[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_4_bn        │ (None, 32, 32,    │      1,024 │ conv_pw_4[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_4_relu      │ (None, 32, 32,    │          0 │ conv_pw_4_bn[0][… │
# │ (ReLU)              │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_5           │ (None, 32, 32,    │      2,304 │ conv_pw_4_relu[0… │
# │ (DepthwiseConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_5_bn        │ (None, 32, 32,    │      1,024 │ conv_dw_5[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_5_relu      │ (None, 32, 32,    │          0 │ conv_dw_5_bn[0][… │
# │ (ReLU)              │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_5 (Conv2D)  │ (None, 32, 32,    │     65,536 │ conv_dw_5_relu[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_5_bn        │ (None, 32, 32,    │      1,024 │ conv_pw_5[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_5_relu      │ (None, 32, 32,    │          0 │ conv_pw_5_bn[0][… │
# │ (ReLU)              │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pad_6          │ (None, 33, 33,    │          0 │ conv_pw_5_relu[0… │
# │ (ZeroPadding2D)     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_6           │ (None, 16, 16,    │      2,304 │ conv_pad_6[0][0]  │
# │ (DepthwiseConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_6_bn        │ (None, 16, 16,    │      1,024 │ conv_dw_6[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_6_relu      │ (None, 16, 16,    │          0 │ conv_dw_6_bn[0][… │
# │ (ReLU)              │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_6 (Conv2D)  │ (None, 16, 16,    │    131,072 │ conv_dw_6_relu[0… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_6_bn        │ (None, 16, 16,    │      2,048 │ conv_pw_6[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_6_relu      │ (None, 16, 16,    │          0 │ conv_pw_6_bn[0][… │
# │ (ReLU)              │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_7           │ (None, 16, 16,    │      4,608 │ conv_pw_6_relu[0… │
# │ (DepthwiseConv2D)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_7_bn        │ (None, 16, 16,    │      2,048 │ conv_dw_7[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_7_relu      │ (None, 16, 16,    │          0 │ conv_dw_7_bn[0][… │
# │ (ReLU)              │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_7 (Conv2D)  │ (None, 16, 16,    │    262,144 │ conv_dw_7_relu[0… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_7_bn        │ (None, 16, 16,    │      2,048 │ conv_pw_7[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_7_relu      │ (None, 16, 16,    │          0 │ conv_pw_7_bn[0][… │
# │ (ReLU)              │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_8           │ (None, 16, 16,    │      4,608 │ conv_pw_7_relu[0… │
# │ (DepthwiseConv2D)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_8_bn        │ (None, 16, 16,    │      2,048 │ conv_dw_8[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_8_relu      │ (None, 16, 16,    │          0 │ conv_dw_8_bn[0][… │
# │ (ReLU)              │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_8 (Conv2D)  │ (None, 16, 16,    │    262,144 │ conv_dw_8_relu[0… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_8_bn        │ (None, 16, 16,    │      2,048 │ conv_pw_8[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_8_relu      │ (None, 16, 16,    │          0 │ conv_pw_8_bn[0][… │
# │ (ReLU)              │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_9           │ (None, 16, 16,    │      4,608 │ conv_pw_8_relu[0… │
# │ (DepthwiseConv2D)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_9_bn        │ (None, 16, 16,    │      2,048 │ conv_dw_9[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_9_relu      │ (None, 16, 16,    │          0 │ conv_dw_9_bn[0][… │
# │ (ReLU)              │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_9 (Conv2D)  │ (None, 16, 16,    │    262,144 │ conv_dw_9_relu[0… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_9_bn        │ (None, 16, 16,    │      2,048 │ conv_pw_9[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_9_relu      │ (None, 16, 16,    │          0 │ conv_pw_9_bn[0][… │
# │ (ReLU)              │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_10          │ (None, 16, 16,    │      4,608 │ conv_pw_9_relu[0… │
# │ (DepthwiseConv2D)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_10_bn       │ (None, 16, 16,    │      2,048 │ conv_dw_10[0][0]  │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_10_relu     │ (None, 16, 16,    │          0 │ conv_dw_10_bn[0]… │
# │ (ReLU)              │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_10 (Conv2D) │ (None, 16, 16,    │    262,144 │ conv_dw_10_relu[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_10_bn       │ (None, 16, 16,    │      2,048 │ conv_pw_10[0][0]  │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_10_relu     │ (None, 16, 16,    │          0 │ conv_pw_10_bn[0]… │
# │ (ReLU)              │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_11          │ (None, 16, 16,    │      4,608 │ conv_pw_10_relu[… │
# │ (DepthwiseConv2D)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_11_bn       │ (None, 16, 16,    │      2,048 │ conv_dw_11[0][0]  │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_dw_11_relu     │ (None, 16, 16,    │          0 │ conv_dw_11_bn[0]… │
# │ (ReLU)              │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_11 (Conv2D) │ (None, 16, 16,    │    262,144 │ conv_dw_11_relu[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_11_bn       │ (None, 16, 16,    │      2,048 │ conv_pw_11[0][0]  │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_pw_11_relu     │ (None, 16, 16,    │          0 │ conv_pw_11_bn[0]… │
# │ (ReLU)              │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 32, 32, 3) │          0 │ input_layer[0][0] │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ conv_pw_1_relu[0… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ conv_pw_3_relu[0… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 32, 32,    │          0 │ conv_pw_11_relu[… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 32, 32,    │      1,792 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 32, 32,    │     36,928 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 32, 32,    │     73,792 │ max_pooling2d_2[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 32, 32,    │    147,520 │ conv_pw_5_relu[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │    294,976 │ up_sampling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 32, 32,    │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ activation[0][0], │
# │ (Concatenate)       │ 320)              │            │ activation_1[0][… │
# │                     │                   │            │ activation_2[0][… │
# │                     │                   │            │ activation_3[0][… │
# │                     │                   │            │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │    921,920 │ concatenate[0][0] │
# │                     │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,280 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 64, 64, 3) │          0 │ input_layer[0][0] │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 64, 64,    │          0 │ conv_pw_1_relu[0… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 64, 64,    │          0 │ activation_5[0][… │
# │ (UpSampling2D)      │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 64, 64,    │          0 │ conv_pw_11_relu[… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 64,    │      1,792 │ max_pooling2d_3[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 64,    │     36,928 │ max_pooling2d_4[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 64, 64,    │     73,792 │ conv_pw_3_relu[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 64, 64,    │    184,384 │ up_sampling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 64, 64,    │    294,976 │ up_sampling2d_2[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ activation_6[0][… │
# │ (Concatenate)       │ 320)              │            │ activation_7[0][… │
# │                     │                   │            │ activation_8[0][… │
# │                     │                   │            │ activation_9[0][… │
# │                     │                   │            │ activation_10[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 64, 64,    │    921,920 │ concatenate_1[0]… │
# │                     │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,280 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 128, 128,  │          0 │ input_layer[0][0] │
# │ (MaxPooling2D)      │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 128, 128,  │          0 │ activation_11[0]… │
# │ (UpSampling2D)      │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_4     │ (None, 128, 128,  │          0 │ activation_5[0][… │
# │ (UpSampling2D)      │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_5     │ (None, 128, 128,  │          0 │ conv_pw_11_relu[… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 128, 128,  │      1,792 │ max_pooling2d_5[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 128, 128,  │     36,928 │ conv_pw_1_relu[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │    184,384 │ up_sampling2d_3[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │    184,384 │ up_sampling2d_4[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 128, 128,  │    294,976 │ up_sampling2d_5[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ activation_12[0]… │
# │ (Concatenate)       │ 320)              │            │ activation_13[0]… │
# │                     │                   │            │ activation_14[0]… │
# │                     │                   │            │ activation_15[0]… │
# │                     │                   │            │ activation_16[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 128, 128,  │    921,920 │ concatenate_2[0]… │
# │                     │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │      1,280 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_6     │ (None, 256, 256,  │          0 │ activation_17[0]… │
# │ (UpSampling2D)      │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_7     │ (None, 256, 256,  │          0 │ activation_11[0]… │
# │ (UpSampling2D)      │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_8     │ (None, 256, 256,  │          0 │ activation_5[0][… │
# │ (UpSampling2D)      │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_9     │ (None, 256, 256,  │          0 │ conv_pw_11_relu[… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │      1,792 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 256, 256,  │    184,384 │ up_sampling2d_6[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 256, 256,  │    184,384 │ up_sampling2d_7[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 256, 256,  │    184,384 │ up_sampling2d_8[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 256, 256,  │    294,976 │ up_sampling2d_9[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ activation_18[0]… │
# │ (Concatenate)       │ 320)              │            │ activation_19[0]… │
# │                     │                   │            │ activation_20[0]… │
# │                     │                   │            │ activation_21[0]… │
# │                     │                   │            │ activation_22[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 256, 256,  │    921,920 │ concatenate_3[0]… │
# │                     │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │      1,280 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 256, 256,  │      2,881 │ activation_23[0]… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 256, 256,  │          0 │ conv2d_24[0][0]   │
# │ (Activation)        │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,027,905 (30.62 MB)
#  Trainable params: 8,008,065 (30.55 MB)
#  Non-trainable params: 19,840 (77.50 KB)

# %%
import numpy as np
import tensorflow as tf

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import keras
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Adam, SGD
from sklearn.model_selection import train_test_split
# from model import unet3plus
# from metrics import dice_loss, dice_coef

IMG_H = 256
IMG_W = 256

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def load_dataset(path, split=0.1):
    """ Loading the images and masks """
    X = sorted(glob(os.path.join(path, "images", "*")))
    Y = sorted(glob(os.path.join(path, "masks", "*")))

    """ Spliting the data into training and testing """
    split_size = int(len(X) * split)

    train_x, valid_x = train_test_split(X, test_size=split_size, random_state=42)
    train_y, valid_y = train_test_split(Y, test_size=split_size, random_state=42)

    train_x, test_x = train_test_split(train_x, test_size=split_size, random_state=42)
    train_y, test_y = train_test_split(train_y, test_size=split_size, random_state=42)

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

def read_image(path):
    path = path.decode()
    image = cv2.imread(path, cv2.IMREAD_COLOR)
    image = cv2.resize(image, (IMG_W, IMG_H))
    image = image / 255.0
    image = image.astype(np.float32)
    return image

def read_mask(path):
    path = path.decode()
    mask = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    mask = cv2.resize(mask, (IMG_W, IMG_H))
    mask = mask / 255.0
    mask = mask.astype(np.float32)
    mask = np.expand_dims(mask, axis=-1)
    return mask

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([IMG_H, IMG_W, 3])
    y.set_shape([IMG_H, IMG_W, 1])
    return x, y

def tf_dataset(X, Y, batch=2):
    ds = tf.data.Dataset.from_tensor_slices((X, Y))
    ds = ds.map(tf_parse).batch(batch).prefetch(10)
    return ds

if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("files")

    """ Hyperparameters """
    batch_size = 2
    lr = 1e-4
    num_epochs = 100
    model_path = os.path.join("files", "model.keras")
    csv_path = os.path.join("files", "log.csv")

    """ Dataset """
    dataset_path = "/kaggle/input/kvasir-seg/Kvasir-SEG"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_dataset(dataset_path)

    print(f"Train: \t{len(train_x)} - {len(train_y)}")
    print(f"Valid: \t{len(valid_x)} - {len(valid_y)}")
    print(f"Test: \t{len(test_x)} - {len(test_y)}")

    train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
    valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)

    """ Model """
    model = unet3plus((IMG_H, IMG_W, 3))
    model.compile(loss=dice_loss, optimizer=Adam(lr), metrics=[dice_coef, keras.metrics.MeanIoU(num_classes=2)])
    # model.summary()

    callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-10, verbose=1),
        CSVLogger(csv_path),
        EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=False)
    ]

    model.fit(
        train_dataset,
        epochs=num_epochs,
        validation_data=valid_dataset,
        callbacks=callbacks
    )
# Out:
# Train: 	800 - 800
# Valid: 	100 - 100
# Test: 	100 - 100
# /tmp/ipykernel_33/1789967653.py:29: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   encoder = MobileNet(include_top=False, weights="imagenet",
# Epoch 1/100
# 2024-05-23 11:03:39.723278: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 3.25729, expected 2.60868
# 2024-05-23 11:03:39.723350: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 3.51493, expected 2.86632
# 2024-05-23 11:03:39.723359: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 4.30991, expected 3.6613
# 2024-05-23 11:03:39.723367: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 4.61844, expected 3.96984
# 2024-05-23 11:03:39.723375: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 4.70488, expected 4.05627
# 2024-05-23 11:03:39.723383: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 5.11794, expected 4.46933
# 2024-05-23 11:03:39.723390: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 4.56915, expected 3.92054
# 2024-05-23 11:03:39.723398: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 4.19583, expected 3.54722
# 2024-05-23 11:03:39.723406: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 3.95712, expected 3.30851
# 2024-05-23 11:03:39.723414: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 10: 4.39247, expected 3.74386
# 2024-05-23 11:03:39.727084: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[2,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,3,256,256]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-23 11:03:39.727123: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-23 11:03:39.727131: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-23 11:03:39.727139: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-23 11:03:39.727146: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-23 11:03:39.727162: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-05-23 11:03:39.888631: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 3.25729, expected 2.60868
# 2024-05-23 11:03:39.888690: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 3.51493, expected 2.86632
# 2024-05-23 11:03:39.888699: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 4.30991, expected 3.6613
# 2024-05-23 11:03:39.888706: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 4.61844, expected 3.96984
# 2024-05-23 11:03:39.888714: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 4.70488, expected 4.05627
# 2024-05-23 11:03:39.888722: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 5.11794, expected 4.46933
# 2024-05-23 11:03:39.888729: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 4.56915, expected 3.92054
# 2024-05-23 11:03:39.888739: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 4.19583, expected 3.54722
# 2024-05-23 11:03:39.888746: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 3.95712, expected 3.30851
# 2024-05-23 11:03:39.888754: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 10: 4.39247, expected 3.74386
# 2024-05-23 11:03:39.892350: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[2,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,3,256,256]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-23 11:03:39.892386: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-23 11:03:39.892395: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-23 11:03:39.892403: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-23 11:03:39.892410: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-23 11:03:39.892425: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-05-23 11:03:39.954873: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 4.56543, expected 3.80355
# 2024-05-23 11:03:39.954940: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 6.4627, expected 5.70082
# 2024-05-23 11:03:39.954966: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 5.3492, expected 4.58732
# 2024-05-23 11:03:39.954974: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 5.43624, expected 4.67436
# 2024-05-23 11:03:39.954982: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 4.93471, expected 4.17284
# 2024-05-23 11:03:39.954990: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 4.75493, expected 3.99306
# 2024-05-23 11:03:39.954999: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 4.27207, expected 3.51019
# 2024-05-23 11:03:39.955007: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 4.04723, expected 3.28535
# 2024-05-23 11:03:39.955015: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 10: 4.97058, expected 4.2087
# 2024-05-23 11:03:39.955023: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 11: 5.67369, expected 4.91181
# 2024-05-23 11:03:39.955881: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[2,64,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,3,128,128]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-23 11:03:39.955909: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-23 11:03:39.955917: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-23 11:03:39.955924: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-23 11:03:39.955931: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-23 11:03:39.955944: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-05-23 11:03:39.995576: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 4.56543, expected 3.80355
# 2024-05-23 11:03:39.995642: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 6.4627, expected 5.70082
# 2024-05-23 11:03:39.995651: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 5.3492, expected 4.58732
# 2024-05-23 11:03:39.995660: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 5.43624, expected 4.67436
# 2024-05-23 11:03:39.995668: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 4.93471, expected 4.17284
# 2024-05-23 11:03:39.995675: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 4.75493, expected 3.99306
# 2024-05-23 11:03:39.995683: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 4.27207, expected 3.51019
# 2024-05-23 11:03:39.995690: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 4.04723, expected 3.28535
# 2024-05-23 11:03:39.995698: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 10: 4.97058, expected 4.2087
# 2024-05-23 11:03:39.995706: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 11: 5.67369, expected 4.91181
# 2024-05-23 11:03:39.995735: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[2,64,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,3,128,128]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-23 11:03:39.995759: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-23 11:03:39.995771: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-23 11:03:39.995787: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-23 11:03:39.995799: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-23 11:03:39.995819: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1716462261.494575      98 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - dice_coef: 0.6433 - loss: 0.3567 - mean_io_u: 0.5348
# Epoch 1: val_loss improved from inf to 0.20197, saving model to files/model.keras
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 172s 245ms/step - dice_coef: 0.6435 - loss: 0.3565 - mean_io_u: 0.5348 - val_dice_coef: 0.7980 - val_loss: 0.2020 - val_mean_io_u: 0.7047 - learning_rate: 1.0000e-04
# Epoch 2/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - dice_coef: 0.8186 - loss: 0.1814 - mean_io_u: 0.6101
# Epoch 2: val_loss improved from 0.20197 to 0.19227, saving model to files/model.keras
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 93s 233ms/step - dice_coef: 0.8186 - loss: 0.1814 - mean_io_u: 0.6101 - val_dice_coef: 0.8077 - val_loss: 0.1923 - val_mean_io_u: 0.5890 - learning_rate: 1.0000e-04
# Epoch 3/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - dice_coef: 0.8824 - loss: 0.1176 - mean_io_u: 0.6186
# Epoch 3: val_loss improved from 0.19227 to 0.18116, saving model to files/model.keras
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 93s 233ms/step - dice_coef: 0.8824 - loss: 0.1176 - mean_io_u: 0.6185 - val_dice_coef: 0.8188 - val_loss: 0.1812 - val_mean_io_u: 0.5646 - learning_rate: 1.0000e-04
# Epoch 4/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - dice_coef: 0.9148 - loss: 0.0852 - mean_io_u: 0.6602
# Epoch 4: val_loss improved from 0.18116 to 0.17393, saving model to files/model.keras
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 93s 233ms/step - dice_coef: 0.9148 - loss: 0.0852 - mean_io_u: 0.6602 - val_dice_coef: 0.8261 - val_loss: 0.1739 - val_mean_io_u: 0.6176 - learning_rate: 1.0000e-04
# Epoch 5/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - dice_coef: 0.9334 - loss: 0.0666 - mean_io_u: 0.7079
# Epoch 5: val_loss improved from 0.17393 to 0.16841, saving model to files/model.keras
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 93s 233ms/step - dice_coef: 0.9334 - loss: 0.0666 - mean_io_u: 0.7079 - val_dice_coef: 0.8316 - val_loss: 0.1684 - val_mean_io_u: 0.6167 - learning_rate: 1.0000e-04
# Epoch 6/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - dice_coef: 0.9393 - loss: 0.0607 - mean_io_u: 0.7234
# Epoch 6: val_loss improved from 0.16841 to 0.16432, saving model to files/model.keras
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 93s 233ms/step - dice_coef: 0.9393 - loss: 0.0607 - mean_io_u: 0.7234 - val_dice_coef: 0.8357 - val_loss: 0.1643 - val_mean_io_u: 0.6690 - learning_rate: 1.0000e-04
# Epoch 7/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - dice_coef: 0.9408 - loss: 0.0592 - mean_io_u: 0.7489
# Epoch 7: val_loss improved from 0.16432 to 0.15046, saving model to files/model.keras
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 93s 233ms/step - dice_coef: 0.9408 - loss: 0.0592 - mean_io_u: 0.7489 - val_dice_coef: 0.8495 - val_loss: 0.1505 - val_mean_io_u: 0.7691 - learning_rate: 1.0000e-04
# Epoch 8/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - dice_coef: 0.9526 - loss: 0.0474 - mean_io_u: 0.7724
# Epoch 8: val_loss did not improve from 0.15046
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 92s 231ms/step - dice_coef: 0.9526 - loss: 0.0474 - mean_io_u: 0.7724 - val_dice_coef: 0.8433 - val_loss: 0.1567 - val_mean_io_u: 0.7095 - learning_rate: 1.0000e-04
# Epoch 9/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - dice_coef: 0.9561 - loss: 0.0439 - mean_io_u: 0.7854
# Epoch 9: val_loss did not improve from 0.15046
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 92s 231ms/step - dice_coef: 0.9561 - loss: 0.0439 - mean_io_u: 0.7854 - val_dice_coef: 0.8425 - val_loss: 0.1575 - val_mean_io_u: 0.7380 - learning_rate: 1.0000e-04
# Epoch 10/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - dice_coef: 0.9603 - loss: 0.0397 - mean_io_u: 0.8157
# Epoch 10: val_loss improved from 0.15046 to 0.14517, saving model to files/model.keras
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 93s 233ms/step - dice_coef: 0.9603 - loss: 0.0397 - mean_io_u: 0.8157 - val_dice_coef: 0.8548 - val_loss: 0.1452 - val_mean_io_u: 0.6582 - learning_rate: 1.0000e-04
# Epoch 11/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - dice_coef: 0.9642 - loss: 0.0358 - mean_io_u: 0.8371
# Epoch 11: val_loss improved from 0.14517 to 0.14207, saving model to files/model.keras
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 93s 233ms/step - dice_coef: 0.9642 - loss: 0.0358 - mean_io_u: 0.8371 - val_dice_coef: 0.8579 - val_loss: 0.1421 - val_mean_io_u: 0.7045 - learning_rate: 1.0000e-04
# Epoch 12/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - dice_coef: 0.9687 - loss: 0.0313 - mean_io_u: 0.8650
# Epoch 12: val_loss did not improve from 0.14207
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 93s 232ms/step - dice_coef: 0.9687 - loss: 0.0313 - mean_io_u: 0.8649 - val_dice_coef: 0.8526 - val_loss: 0.1474 - val_mean_io_u: 0.7521 - learning_rate: 1.0000e-04
# Epoch 13/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - dice_coef: 0.9705 - loss: 0.0295 - mean_io_u: 0.8693
# Epoch 13: val_loss did not improve from 0.14207
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 93s 231ms/step - dice_coef: 0.9705 - loss: 0.0295 - mean_io_u: 0.8693 - val_dice_coef: 0.8518 - val_loss: 0.1482 - val_mean_io_u: 0.7460 - learning_rate: 1.0000e-04
# Epoch 14/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - dice_coef: 0.9705 - loss: 0.0295 - mean_io_u: 0.8748
# Epoch 14: val_loss did not improve from 0.14207
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 92s 231ms/step - dice_coef: 0.9705 - loss: 0.0295 - mean_io_u: 0.8747 - val_dice_coef: 0.8442 - val_loss: 0.1558 - val_mean_io_u: 0.7172 - learning_rate: 1.0000e-04
# Epoch 15/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - dice_coef: 0.9708 - loss: 0.0292 - mean_io_u: 0.8582
# Epoch 15: val_loss did not improve from 0.14207
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 92s 231ms/step - dice_coef: 0.9708 - loss: 0.0292 - mean_io_u: 0.8581 - val_dice_coef: 0.8377 - val_loss: 0.1623 - val_mean_io_u: 0.7721 - learning_rate: 1.0000e-04
# Epoch 16/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - dice_coef: 0.9669 - loss: 0.0331 - mean_io_u: 0.8466
# Epoch 16: val_loss did not improve from 0.14207
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 92s 231ms/step - dice_coef: 0.9669 - loss: 0.0331 - mean_io_u: 0.8466 - val_dice_coef: 0.8371 - val_loss: 0.1629 - val_mean_io_u: 0.6885 - learning_rate: 1.0000e-04
# Epoch 17/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - dice_coef: 0.9657 - loss: 0.0343 - mean_io_u: 0.8542
# Epoch 17: val_loss did not improve from 0.14207
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 93s 231ms/step - dice_coef: 0.9657 - loss: 0.0343 - mean_io_u: 0.8542 - val_dice_coef: 0.8495 - val_loss: 0.1505 - val_mean_io_u: 0.7092 - learning_rate: 1.0000e-05
# Epoch 18/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - dice_coef: 0.9752 - loss: 0.0248 - mean_io_u: 0.8764
# Epoch 18: val_loss did not improve from 0.14207
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 93s 231ms/step - dice_coef: 0.9752 - loss: 0.0248 - mean_io_u: 0.8764 - val_dice_coef: 0.8498 - val_loss: 0.1502 - val_mean_io_u: 0.7206 - learning_rate: 1.0000e-05
# Epoch 19/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - dice_coef: 0.9772 - loss: 0.0228 - mean_io_u: 0.8866
# Epoch 19: val_loss did not improve from 0.14207
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 93s 231ms/step - dice_coef: 0.9772 - loss: 0.0228 - mean_io_u: 0.8866 - val_dice_coef: 0.8510 - val_loss: 0.1490 - val_mean_io_u: 0.7261 - learning_rate: 1.0000e-05
# Epoch 20/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - dice_coef: 0.9785 - loss: 0.0215 - mean_io_u: 0.8921
# Epoch 20: val_loss did not improve from 0.14207
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 93s 231ms/step - dice_coef: 0.9785 - loss: 0.0215 - mean_io_u: 0.8921 - val_dice_coef: 0.8508 - val_loss: 0.1492 - val_mean_io_u: 0.7300 - learning_rate: 1.0000e-05
# Epoch 21/100
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - dice_coef: 0.9796 - loss: 0.0204 - mean_io_u: 0.8978
# Epoch 21: val_loss did not improve from 0.14207
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 93s 232ms/step - dice_coef: 0.9796 - loss: 0.0204 - mean_io_u: 0.8978 - val_dice_coef: 0.8518 - val_loss: 0.1482 - val_mean_io_u: 0.7328 - learning_rate: 1.0000e-05

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import numpy as np
import cv2
import imageio
from glob import glob
from tqdm import tqdm
import tensorflow as tf
# from train import create_dir, load_dataset
# from metrics import dice_loss, dice_coef

IMG_H = 256
IMG_W = 256

if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir(f"results")

    """ Load the model """
    model_path = os.path.join("files", "model.keras")
    model = tf.keras.models.load_model(model_path, custom_objects={"dice_loss": dice_loss, "dice_coef": dice_coef})

    """ Dataset """
    dataset_path = "/kaggle/input/kvasir-seg/Kvasir-SEG"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_dataset(dataset_path)

    print(f"Train: \t{len(train_x)} - {len(train_y)}")
    print(f"Valid: \t{len(valid_x)} - {len(valid_y)}")
    print(f"Test: \t{len(test_x)} - {len(test_y)}")

    """ Prediction """
    for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
        """ Extracting the name """
        name = x.split("/")[-1].split(".")[0]

        """ Reading the image """
        image = cv2.imread(x, cv2.IMREAD_COLOR)
        image = cv2.resize(image, (IMG_W, IMG_H))
        x = image / 255.0
        x = np.expand_dims(x, axis=0)

        """ Read Mask """
        mask = cv2.imread(y, cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, (IMG_W, IMG_H))
        mask = mask / 255.0
        mask = np.expand_dims(mask, axis=-1)
        mask = np.concatenate([mask, mask, mask], axis=-1)

        """ Prediction """
        pred = model.predict(x, verbose=0)[0]
        pred = np.concatenate([pred, pred, pred], axis=-1)
        # pred = (pred > 0.5).astype(np.int32)

        """ Save final mask """
        line = np.ones((IMG_H, 10, 3)) * 255
        cat_images = np.concatenate([image, line, mask*255, line, pred*255], axis=1)
        save_image_path = os.path.join("results",  f"{name}.jpg")
        cv2.imwrite(save_image_path, cat_images)
# Out:
# Train: 	800 - 800
# Valid: 	100 - 100
# Test: 	100 - 100
#   0%|          | 0/100 [00:00<?, ?it/s]2024-05-23 11:44:19.916550: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 2.86272, expected 2.0465
# 2024-05-23 11:44:19.916626: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 4.04967, expected 3.23345
# 2024-05-23 11:44:19.916635: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 4.4326, expected 3.61638
# 2024-05-23 11:44:19.916643: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 5.46868, expected 4.65247
# 2024-05-23 11:44:19.916651: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 5.37814, expected 4.56193
# 2024-05-23 11:44:19.916676: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 5.18374, expected 4.36753
# 2024-05-23 11:44:19.916684: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 5.54872, expected 4.7325
# 2024-05-23 11:44:19.916692: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 5.78654, expected 4.97032
# 2024-05-23 11:44:19.916700: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 4.0901, expected 3.27388
# 2024-05-23 11:44:19.916709: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 5.11265, expected 4.29643
# 2024-05-23 11:44:19.916731: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[1,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,3,256,256]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-23 11:44:19.916741: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-23 11:44:19.916748: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-23 11:44:19.916755: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-23 11:44:19.916763: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-23 11:44:19.916777: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-05-23 11:44:19.975653: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 2.86272, expected 2.0465
# 2024-05-23 11:44:19.975720: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 4.04967, expected 3.23345
# 2024-05-23 11:44:19.975733: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 4.4326, expected 3.61638
# 2024-05-23 11:44:19.975747: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 5.46868, expected 4.65247
# 2024-05-23 11:44:19.975761: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 5.37814, expected 4.56193
# 2024-05-23 11:44:19.975773: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 5.18374, expected 4.36753
# 2024-05-23 11:44:19.975784: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 5.54872, expected 4.7325
# 2024-05-23 11:44:19.975794: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 5.78654, expected 4.97032
# 2024-05-23 11:44:19.975806: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 4.0901, expected 3.27388
# 2024-05-23 11:44:19.975817: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 5.11265, expected 4.29643
# 2024-05-23 11:44:19.975848: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[1,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,3,256,256]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-23 11:44:19.975864: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-23 11:44:19.975877: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-23 11:44:19.975889: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-23 11:44:19.975901: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-23 11:44:19.975923: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-05-23 11:44:20.022841: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32768: 3.66788, expected 2.82077
# 2024-05-23 11:44:20.022903: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32769: 5.27059, expected 4.42348
# 2024-05-23 11:44:20.022915: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32770: 5.00058, expected 4.15347
# 2024-05-23 11:44:20.022929: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32771: 4.72297, expected 3.87586
# 2024-05-23 11:44:20.022943: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32772: 4.5861, expected 3.73899
# 2024-05-23 11:44:20.022953: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32773: 4.17555, expected 3.32844
# 2024-05-23 11:44:20.022963: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32774: 3.43326, expected 2.58615
# 2024-05-23 11:44:20.022974: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32775: 3.61347, expected 2.76636
# 2024-05-23 11:44:20.022984: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32776: 2.90622, expected 2.05911
# 2024-05-23 11:44:20.022995: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32777: 3.1097, expected 2.26259
# 2024-05-23 11:44:20.023020: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[1,64,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,3,128,128]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-23 11:44:20.023035: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-23 11:44:20.023048: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-23 11:44:20.023058: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-23 11:44:20.023070: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-23 11:44:20.023087: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-05-23 11:44:20.047527: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32768: 3.66788, expected 2.82077
# 2024-05-23 11:44:20.047599: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32769: 5.27059, expected 4.42348
# 2024-05-23 11:44:20.047618: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32770: 5.00058, expected 4.15347
# 2024-05-23 11:44:20.047629: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32771: 4.72297, expected 3.87586
# 2024-05-23 11:44:20.047640: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32772: 4.5861, expected 3.73899
# 2024-05-23 11:44:20.047652: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32773: 4.17555, expected 3.32844
# 2024-05-23 11:44:20.047663: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32774: 3.43326, expected 2.58615
# 2024-05-23 11:44:20.047674: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32775: 3.61347, expected 2.76636
# 2024-05-23 11:44:20.047687: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32776: 2.90622, expected 2.05911
# 2024-05-23 11:44:20.047701: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 32777: 3.1097, expected 2.26259
# 2024-05-23 11:44:20.047728: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[1,64,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,3,128,128]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-23 11:44:20.047749: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-23 11:44:20.047762: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-23 11:44:20.047773: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-23 11:44:20.047785: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-23 11:44:20.047804: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 100%|██████████| 100/100 [00:23<00:00,  4.24it/s]

# %%
test_dataset = tf_dataset(test_x, test_y, batch=batch_size)

# %%
results = model.evaluate(test_dataset)
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 94ms/step - dice_coef: 0.8586 - loss: 0.1414 - mean_io_u: 0.7422

# %%
# !zip -r file.zip /kaggle/working
# Out:
#   adding: kaggle/working/ (stored 0%)
#   adding: kaggle/working/results/ (stored 0%)
#   adding: kaggle/working/results/cju2zrojo9kcd0878ld2epejq.jpg (deflated 11%)
#   adding: kaggle/working/results/cju1euuc65wm00799m4sjdnnn.jpg (deflated 11%)
#   adding: kaggle/working/results/cju1b75x63ddl0799sdp0i2j3.jpg (deflated 12%)
#   adding: kaggle/working/results/cju5ca9hcatkc0801jzwe7tfx.jpg (deflated 7%)
#   adding: kaggle/working/results/cju7ev2b12owa08500bpfpwyw.jpg (deflated 8%)
#   adding: kaggle/working/results/cju88l66no10s0850rsda7ej1.jpg (deflated 6%)
#   adding: kaggle/working/results/ck2bxskgxxzfv08386xkqtqdy.jpg (deflated 10%)
#   adding: kaggle/working/results/cju7b3f5h1sm40755i572jden.jpg (deflated 9%)
#   adding: kaggle/working/results/cju5wuhm1lwm40987vugqn3vv.jpg (deflated 10%)
#   adding: kaggle/working/results/cju83h9ysjwe808716nt35oah.jpg (deflated 11%)
#   adding: kaggle/working/results/cju0sxqiclckk08551ycbwhno.jpg (deflated 10%)
#   adding: kaggle/working/results/cju7efffp2ivf0817etg3jehl.jpg (deflated 7%)
#   adding: kaggle/working/results/cju89z6pqpqfx0817mfv8ixjc.jpg (deflated 13%)
#   adding: kaggle/working/results/cju8bm24yrrdp081829mbo8ic.jpg (deflated 10%)
#   adding: kaggle/working/results/cju8bljw9rqk20801kr54akrl.jpg (deflated 8%)
#   adding: kaggle/working/results/cju1aqqv02qwz0878a5cyhr67.jpg (deflated 9%)
#   adding: kaggle/working/results/cju8402x1kcy70801t6kz6bdi.jpg (deflated 7%)
#   adding: kaggle/working/results/cju5u6wf0kh1t0755bg1ssixv.jpg (deflated 7%)
#   adding: kaggle/working/results/cju33za6l2qy70988jhrlp2ev.jpg (deflated 10%)
#   adding: kaggle/working/results/cju183od81ff608017ekzif89.jpg (deflated 8%)
#   adding: kaggle/working/results/cju7dsrtb2f8i085064kwugfk.jpg (deflated 12%)
#   adding: kaggle/working/results/cju87zv8lni0o0850hbbecbq6.jpg (deflated 8%)
#   adding: kaggle/working/results/cju7dymur2od30755eg8yv2ht.jpg (deflated 10%)
#   adding: kaggle/working/results/cju0vtox5ain6099360pu62rp.jpg (deflated 12%)
#   adding: kaggle/working/results/cju6wi3akvn8r0801px8eligc.jpg (deflated 6%)
#   adding: kaggle/working/results/cju8alhigqn2h0801zksudldd.jpg (deflated 7%)
#   adding: kaggle/working/results/cju2qozsk20cq0855ugrg3cri.jpg (deflated 7%)
#   adding: kaggle/working/results/cju6xlygpw7bs0818n691jsq4.jpg (deflated 8%)
#   adding: kaggle/working/results/cju2oq5570avm079959o20op1.jpg (deflated 9%)
#   adding: kaggle/working/results/cju17g6ykn1cs0993dww6qdi8.jpg (deflated 7%)
#   adding: kaggle/working/results/cju35fxqyzt5p0993vusm54qz.jpg (deflated 9%)
#   adding: kaggle/working/results/cju2tjrog4jy30878pawyazqc.jpg (deflated 10%)
#   adding: kaggle/working/results/cju0sr5ghl0nd08789uzf1raf.jpg (deflated 6%)
#   adding: kaggle/working/results/cju8cwy02t9eq08185qn12c02.jpg (deflated 10%)
#   adding: kaggle/working/results/cju3xiic0ilzp0850lusrb42j.jpg (deflated 15%)
#   adding: kaggle/working/results/cju7agj961l2r0818z29iq8yn.jpg (deflated 13%)
#   adding: kaggle/working/results/cju7db7lp2f400755tntd1ohf.jpg (deflated 8%)
#   adding: kaggle/working/results/cju84dsvaklpx098750hp83x4.jpg (deflated 7%)
#   adding: kaggle/working/results/cju439oazm2fu0871ma0vvrft.jpg (deflated 7%)
#   adding: kaggle/working/results/cju5wqonpm0e60801z88ewmy1.jpg (deflated 9%)
#   adding: kaggle/working/results/cjyzkmjy8evns070165gf9dmq.jpg (deflated 11%)
#   adding: kaggle/working/results/cju2xf8e5y2wm08359vcgk09b.jpg (deflated 9%)
#   adding: kaggle/working/results/cju42qet0lsq90871e50xbnuv.jpg (deflated 11%)
#   adding: kaggle/working/results/cju1c8ffau5770835g0g343o8.jpg (deflated 8%)
#   adding: kaggle/working/results/cju1fuoa4wmc50835qfd11sp9.jpg (deflated 10%)
#   adding: kaggle/working/results/cju5fb86jd1jp0755b1ukbhq5.jpg (deflated 9%)
#   adding: kaggle/working/results/cju302fqq9spc0878rrygyzzz.jpg (deflated 7%)
#   adding: kaggle/working/results/cju30525w04r10835ygp257sb.jpg (deflated 10%)
#   adding: kaggle/working/results/cju1ejj7dvqfa0835ra184v5m.jpg (deflated 8%)
#   adding: kaggle/working/results/cju1csmlc4ht10799b8ymmghg.jpg (deflated 10%)
#   adding: kaggle/working/results/cju3x2s11ibzi0817kk284k0j.jpg (deflated 9%)
#   adding: kaggle/working/results/cju7dvl5m2n4t0755hlnnjjet.jpg (deflated 10%)
#   adding: kaggle/working/results/cju15wdt3zla10801odjiw7sy.jpg (deflated 8%)
#   adding: kaggle/working/results/cju8a84g0q76m0818hwiggkod.jpg (deflated 7%)
#   adding: kaggle/working/results/cju40m0rjkpw80871z6n6yg1u.jpg (deflated 7%)
#   adding: kaggle/working/results/cju87z6o6nh73085045bzsx6o.jpg (deflated 11%)
#   adding: kaggle/working/results/cju87tyddnnad0755bj0wxahe.jpg (deflated 6%)
#   adding: kaggle/working/results/cju1hirfi7ekp0855q0vgm9qq.jpg (deflated 9%)
#   adding: kaggle/working/results/cju2txjfzv60w098839dcimys.jpg (deflated 12%)
#   adding: kaggle/working/results/cju5xopi0md7q0871r1sjc1av.jpg (deflated 10%)
#   adding: kaggle/working/results/cju88q6h6obpd0871ckmiabbo.jpg (deflated 9%)
#   adding: kaggle/working/results/cju2wxv0hxs2f09884w48v8fi.jpg (deflated 8%)
#   adding: kaggle/working/results/cju7d2q1k27nf08715zshsckt.jpg (deflated 10%)
#   adding: kaggle/working/results/cju2rn0hasxri0835nfy3buay.jpg (deflated 11%)
#   adding: kaggle/working/results/cju1g4nsb6ngy0799l4ezm8ab.jpg (deflated 9%)
#   adding: kaggle/working/results/cju1hyolc7aqu0878rrkfn1lr.jpg (deflated 10%)
#   adding: kaggle/working/results/cju42u5bjlvi10801dc13sskp.jpg (deflated 10%)
#   adding: kaggle/working/results/cju5fs6j6d8350801vglraq4u.jpg (deflated 8%)
#   adding: kaggle/working/results/cju85ia1slh220987y7c20sm2.jpg (deflated 9%)
#   adding: kaggle/working/results/cju40sdwukv3k0755y99ug1k8.jpg (deflated 8%)
#   adding: kaggle/working/results/cju7et17a2vjk0755e743npl1.jpg (deflated 12%)
#   adding: kaggle/working/results/cju30gxjq0djk0988jytm49rs.jpg (deflated 10%)
#   adding: kaggle/working/results/cju7cue9b232j0801qdzk1ykj.jpg (deflated 11%)
#   adding: kaggle/working/results/cju3uz4o6gr9z0850lhxyxvsj.jpg (deflated 9%)
#   adding: kaggle/working/results/cju34fojcctcf0799ebolbvkn.jpg (deflated 12%)
#   adding: kaggle/working/results/cju6vqarjv7yo0987q4b1btk1.jpg (deflated 10%)
#   adding: kaggle/working/results/cju8cj10qsrau0871o2dr6ai1.jpg (deflated 11%)
#   adding: kaggle/working/results/cju41p90plcsx08018cnzpndc.jpg (deflated 9%)
#   adding: kaggle/working/results/cju3tp94kfstl08181awh6z49.jpg (deflated 7%)
#   adding: kaggle/working/results/cju2wx0gh7fpz0878wwyd9ep8.jpg (deflated 9%)
#   adding: kaggle/working/results/cju1cfhyg48bb0799cl5pr2jh.jpg (deflated 8%)
#   adding: kaggle/working/results/cju5wkonqlrl409877y8zvnub.jpg (deflated 8%)
#   adding: kaggle/working/results/cju326h4v1gxw08352px40p7r.jpg (deflated 6%)
#   adding: kaggle/working/results/cju87kbcen2av0987usezo8kn.jpg (deflated 9%)
#   adding: kaggle/working/results/cju3v11mrgwwb0755u242ygye.jpg (deflated 11%)
#   adding: kaggle/working/results/cju8418jhkf7d0818ga2v0xq0.jpg (deflated 8%)
#   adding: kaggle/working/results/cju83wwn1k55e0850kw6i2d81.jpg (deflated 9%)
#   adding: kaggle/working/results/cju85hguellg50818kwu3s8d1.jpg (deflated 6%)
#   adding: kaggle/working/results/cju7dizi82h2i0755doucgnt3.jpg (deflated 9%)
#   adding: kaggle/working/results/cju43gfosm63n08714rpih8pe.jpg (deflated 9%)
#   adding: kaggle/working/results/cju3u4lxmg59o0755rz42b9en.jpg (deflated 9%)
#   adding: kaggle/working/results/cju6vta3kvazg0817qbeppjtm.jpg (deflated 6%)
#   adding: kaggle/working/results/cju83syhdk6gs0801rf1rekdl.jpg (deflated 9%)
#   adding: kaggle/working/results/cju33mirdc8mj0799k33wzoes.jpg (deflated 7%)
#   adding: kaggle/working/results/cju5huurrecm70801y680y13m.jpg (deflated 10%)
#   adding: kaggle/working/results/cju5h57xedz5h0755mjpc8694.jpg (deflated 6%)
#   adding: kaggle/working/results/cju88cddensj00987788yotmg.jpg (deflated 11%)
#   adding: kaggle/working/results/cju5eq8c8ck690850vix98hv3.jpg (deflated 7%)
#   adding: kaggle/working/results/cju41kd7yl4nm0850gil5qqwh.jpg (deflated 12%)
#   adding: kaggle/working/results/cju7bmi1v1pnj0987pa52jjok.jpg (deflated 9%)
#   adding: kaggle/working/files/ (stored 0%)
#   adding: kaggle/working/files/log.csv (deflated 55%)
#   adding: kaggle/working/files/model.keras (deflated 8%)
#   adding: kaggle/working/.virtual_documents/ (stored 0%)
