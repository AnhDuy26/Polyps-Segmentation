# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import tensorflow as tf
import tensorflow.keras.layers as L
from tensorflow.keras.applications import VGG16

def conv_block(x, num_filters, act=True):
    x = L.Conv2D(num_filters, kernel_size=3, padding="same")(x)

    if act == True:
        x = L.BatchNormalization()(x)
        x = L.Activation("relu")(x)

    return x

def encoder_block(x, num_filters):
    x = conv_block(x, num_filters)
    x = conv_block(x, num_filters)

    p = L.MaxPool2D((2, 2))(x)
    return x, p

def unet3plus(input_shape, num_classes=1):
    """ Inputs """
    inputs = L.Input(input_shape, name="input_layer")

    """ Pre-trained VGG16 Model """
    encoder = VGG16(include_top=False, weights="imagenet", input_tensor=inputs)

    """ Encoder """
    e1 = encoder.get_layer("block1_conv2").output
    e2 = encoder.get_layer("block2_conv2").output
    e3 = encoder.get_layer("block3_conv3").output
    e4 = encoder.get_layer("block4_conv3").output

    """ Bridge """
    e5 = encoder.get_layer("block5_conv3").output

    """ Decoder 4 """
    e1_d4 = L.MaxPool2D((8, 8))(e1)
    e1_d4 = conv_block(e1_d4, 64)

    e2_d4 = L.MaxPool2D((4, 4))(e2)
    e2_d4 = conv_block(e2_d4, 64)

    e3_d4 = L.MaxPool2D((2, 2))(e3)
    e3_d4 = conv_block(e3_d4, 64)

    e4_d4 = conv_block(e4, 64)

    e5_d4 = L.UpSampling2D((2, 2), interpolation="bilinear")(e5)
    e5_d4 = conv_block(e5_d4, 64)

    d4 = L.Concatenate()([e1_d4, e2_d4, e3_d4, e4_d4, e5_d4])
    d4 = conv_block(d4, 64*5)

    """ Decoder 3 """
    e1_d3 = L.MaxPool2D((4, 4))(e1)
    e1_d3 = conv_block(e1_d3, 64)

    e2_d3 = L.MaxPool2D((2, 2))(e2)
    e2_d3 = conv_block(e2_d3, 64)

    e3_d3 = conv_block(e3, 64)

    d4_d3 = L.UpSampling2D((2, 2), interpolation="bilinear")(d4)
    d4_d3 = conv_block(d4_d3, 64)

    e5_d3 = L.UpSampling2D((4, 4), interpolation="bilinear")(e5)
    e5_d3 = conv_block(e5_d3, 64)

    d3 = L.Concatenate()([e1_d3, e2_d3, e3_d3, d4_d3, e5_d3])
    d3 = conv_block(d3, 64*5)

    """ Decoder 2 """
    e1_d2 = L.MaxPool2D((2, 2))(e1)
    e1_d2 = conv_block(e1_d2, 64)

    e2_d2 = conv_block(e2, 64)

    d3_d2 = L.UpSampling2D((2, 2), interpolation="bilinear")(d3)
    d3_d2 = conv_block(d3_d2, 64)

    d4_d2 = L.UpSampling2D((4, 4), interpolation="bilinear")(d4)
    d4_d2 = conv_block(d4_d2, 64)

    e5_d2 = L.UpSampling2D((8, 8), interpolation="bilinear")(e5)
    e5_d2 = conv_block(e5_d2, 64)

    d2 = L.Concatenate()([e1_d2, e2_d2, d3_d2, d4_d2, e5_d2])
    d2 = conv_block(d2, 64*5)

    """ Decoder 1 """
    e1_d1 = conv_block(e1, 64)

    d2_d1 = L.UpSampling2D((2, 2), interpolation="bilinear")(d2)
    d2_d1 = conv_block(d2_d1, 64)

    d3_d1 = L.UpSampling2D((4, 4), interpolation="bilinear")(d3)
    d3_d1 = conv_block(d3_d1, 64)

    d4_d1 = L.UpSampling2D((8, 8), interpolation="bilinear")(d4)
    d4_d1 = conv_block(d4_d1, 64)

    e5_d1 = L.UpSampling2D((16, 16), interpolation="bilinear")(e5)
    e5_d1 = conv_block(e5_d1, 64)

    d1 = L.Concatenate()([e1_d1, d2_d1, d3_d1, d4_d1, e5_d1])
    d1 = conv_block(d1, 64*5)

    """ Output """
    y1 = L.Conv2D(num_classes, kernel_size=3, padding="same")(d1)
    y1 = L.Activation("sigmoid")(y1)
    outputs = [y1]

    model = tf.keras.Model(inputs, outputs)
    return model


if __name__ == "__main__":
    input_shape = (256, 256, 3)
    model = unet3plus(input_shape)
    model.summary()
# Out:
# 2024-05-21 11:08:29.134149: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-21 11:08:29.134235: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-21 11:08:29.271315: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 256, 256,  │      1,792 │ input_layer[0][0] │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv2        │ (None, 256, 256,  │     36,928 │ block1_conv1[0][… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool         │ (None, 128, 128,  │          0 │ block1_conv2[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv1        │ (None, 128, 128,  │     73,856 │ block1_pool[0][0] │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv2        │ (None, 128, 128,  │    147,584 │ block2_conv1[0][… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_pool         │ (None, 64, 64,    │          0 │ block2_conv2[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv1        │ (None, 64, 64,    │    295,168 │ block2_pool[0][0] │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv2        │ (None, 64, 64,    │    590,080 │ block3_conv1[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv3        │ (None, 64, 64,    │    590,080 │ block3_conv2[0][… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_pool         │ (None, 32, 32,    │          0 │ block3_conv3[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv1        │ (None, 32, 32,    │  1,180,160 │ block3_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv2        │ (None, 32, 32,    │  2,359,808 │ block4_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv3        │ (None, 32, 32,    │  2,359,808 │ block4_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_pool         │ (None, 16, 16,    │          0 │ block4_conv3[0][… │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv1        │ (None, 16, 16,    │  2,359,808 │ block4_pool[0][0] │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv2        │ (None, 16, 16,    │  2,359,808 │ block5_conv1[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv3        │ (None, 16, 16,    │  2,359,808 │ block5_conv2[0][… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 32, 32,    │          0 │ block1_conv2[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ block2_conv2[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ block3_conv3[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 32, 32,    │          0 │ block5_conv3[0][… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 32, 32,    │     36,928 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 32, 32,    │     73,792 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 32, 32,    │    147,520 │ max_pooling2d_2[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 32, 32,    │    294,976 │ block4_conv3[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │    294,976 │ up_sampling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 32, 32,    │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ activation[0][0], │
# │ (Concatenate)       │ 320)              │            │ activation_1[0][… │
# │                     │                   │            │ activation_2[0][… │
# │                     │                   │            │ activation_3[0][… │
# │                     │                   │            │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │    921,920 │ concatenate[0][0] │
# │                     │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,280 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 64, 64,    │          0 │ block1_conv2[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 64, 64,    │          0 │ block2_conv2[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 64, 64,    │          0 │ activation_5[0][… │
# │ (UpSampling2D)      │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 64, 64,    │          0 │ block5_conv3[0][… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 64,    │     36,928 │ max_pooling2d_3[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 64,    │     73,792 │ max_pooling2d_4[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 64, 64,    │    147,520 │ block3_conv3[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 64, 64,    │    184,384 │ up_sampling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 64, 64,    │    294,976 │ up_sampling2d_2[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ activation_6[0][… │
# │ (Concatenate)       │ 320)              │            │ activation_7[0][… │
# │                     │                   │            │ activation_8[0][… │
# │                     │                   │            │ activation_9[0][… │
# │                     │                   │            │ activation_10[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 64, 64,    │    921,920 │ concatenate_1[0]… │
# │                     │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,280 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 128, 128,  │          0 │ block1_conv2[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 128, 128,  │          0 │ activation_11[0]… │
# │ (UpSampling2D)      │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_4     │ (None, 128, 128,  │          0 │ activation_5[0][… │
# │ (UpSampling2D)      │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_5     │ (None, 128, 128,  │          0 │ block5_conv3[0][… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 128, 128,  │     36,928 │ max_pooling2d_5[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 128, 128,  │     73,792 │ block2_conv2[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │    184,384 │ up_sampling2d_3[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │    184,384 │ up_sampling2d_4[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 128, 128,  │    294,976 │ up_sampling2d_5[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ activation_12[0]… │
# │ (Concatenate)       │ 320)              │            │ activation_13[0]… │
# │                     │                   │            │ activation_14[0]… │
# │                     │                   │            │ activation_15[0]… │
# │                     │                   │            │ activation_16[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 128, 128,  │    921,920 │ concatenate_2[0]… │
# │                     │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │      1,280 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_6     │ (None, 256, 256,  │          0 │ activation_17[0]… │
# │ (UpSampling2D)      │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_7     │ (None, 256, 256,  │          0 │ activation_11[0]… │
# │ (UpSampling2D)      │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_8     │ (None, 256, 256,  │          0 │ activation_5[0][… │
# │ (UpSampling2D)      │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_9     │ (None, 256, 256,  │          0 │ block5_conv3[0][… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │     36,928 │ block1_conv2[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 256, 256,  │    184,384 │ up_sampling2d_6[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 256, 256,  │    184,384 │ up_sampling2d_7[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 256, 256,  │    184,384 │ up_sampling2d_8[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 256, 256,  │    294,976 │ up_sampling2d_9[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ activation_18[0]… │
# │ (Concatenate)       │ 320)              │            │ activation_19[0]… │
# │                     │                   │            │ activation_20[0]… │
# │                     │                   │            │ activation_21[0]… │
# │                     │                   │            │ activation_22[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 256, 256,  │    921,920 │ concatenate_3[0]… │
# │                     │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │      1,280 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 320)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 256, 256,  │      2,881 │ activation_23[0]… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 256, 256,  │          0 │ conv2d_24[0][0]   │
# │ (Activation)        │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 21,660,801 (82.63 MB)
#  Trainable params: 21,655,681 (82.61 MB)
#  Non-trainable params: 5,120 (20.00 KB)

# %%
import numpy as np
import tensorflow as tf

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import keras
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Adam, SGD
from sklearn.model_selection import train_test_split
# from model import unet3plus
# from metrics import dice_loss, dice_coef

IMG_H = 256
IMG_W = 256

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def load_dataset(path, split=0.1):
    """ Loading the images and masks """
    X = sorted(glob(os.path.join(path, "images", "*")))
    Y = sorted(glob(os.path.join(path, "masks", "*")))

    """ Spliting the data into training and testing """
    split_size = int(len(X) * split)

    train_x, valid_x = train_test_split(X, test_size=split_size, random_state=42)
    train_y, valid_y = train_test_split(Y, test_size=split_size, random_state=42)

    train_x, test_x = train_test_split(train_x, test_size=split_size, random_state=42)
    train_y, test_y = train_test_split(train_y, test_size=split_size, random_state=42)

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

def read_image(path):
    path = path.decode()
    image = cv2.imread(path, cv2.IMREAD_COLOR)
    image = cv2.resize(image, (IMG_W, IMG_H))
    image = image / 255.0
    image = image.astype(np.float32)
    return image

def read_mask(path):
    path = path.decode()
    mask = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    mask = cv2.resize(mask, (IMG_W, IMG_H))
    mask = mask / 255.0
    mask = mask.astype(np.float32)
    mask = np.expand_dims(mask, axis=-1)
    return mask

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([IMG_H, IMG_W, 3])
    y.set_shape([IMG_H, IMG_W, 1])
    return x, y

def tf_dataset(X, Y, batch=2):
    ds = tf.data.Dataset.from_tensor_slices((X, Y))
    ds = ds.map(tf_parse).batch(batch).prefetch(10)
    return ds

if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("files")

    """ Hyperparameters """
    batch_size = 4
    lr = 1e-4
    num_epochs = 100
    model_path = os.path.join("files", "model.keras")
    csv_path = os.path.join("files", "log.csv")

    """ Dataset """
    dataset_path = "/kaggle/input/kvasir-seg/Kvasir-SEG"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_dataset(dataset_path)

    print(f"Train: \t{len(train_x)} - {len(train_y)}")
    print(f"Valid: \t{len(valid_x)} - {len(valid_y)}")
    print(f"Test: \t{len(test_x)} - {len(test_y)}")

    train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
    valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)

    """ Model """
    model = unet3plus((IMG_H, IMG_W, 3))
    model.compile(loss=dice_loss, optimizer=Adam(lr), metrics=[dice_coef, keras.metrics.MeanIoU(num_classes=2)])
    # model.summary()

    callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-10, verbose=1),
        CSVLogger(csv_path),
        EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=False)
    ]

    model.fit(
        train_dataset,
        epochs=num_epochs,
        validation_data=valid_dataset,
        callbacks=callbacks
    )
# Out:
# Train: 	800 - 800
# Valid: 	100 - 100
# Test: 	100 - 100
# Epoch 1/100
# 2024-05-21 11:10:38.679577: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 3.24577, expected 2.80959
# 2024-05-21 11:10:38.679639: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 179: 3.17396, expected 2.73778
# 2024-05-21 11:10:38.680021: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65536: 3.15611, expected 2.41005
# 2024-05-21 11:10:38.680049: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65537: 3.84262, expected 3.09657
# 2024-05-21 11:10:38.680060: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65538: 4.59187, expected 3.84581
# 2024-05-21 11:10:38.680071: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65539: 5.43123, expected 4.68518
# 2024-05-21 11:10:38.680082: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65540: 5.1009, expected 4.35484
# 2024-05-21 11:10:38.680092: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65541: 5.74889, expected 5.00283
# 2024-05-21 11:10:38.680103: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65542: 5.35053, expected 4.60448
# 2024-05-21 11:10:38.680113: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65543: 5.29655, expected 4.5505
# 2024-05-21 11:10:38.687681: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[4,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,3,256,256]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-21 11:10:38.687710: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-21 11:10:38.687718: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-21 11:10:38.687725: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-21 11:10:38.687732: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-21 11:10:38.687748: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-05-21 11:10:38.990097: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 3.24577, expected 2.80959
# 2024-05-21 11:10:38.990154: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 179: 3.17396, expected 2.73778
# 2024-05-21 11:10:38.990532: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65536: 3.15611, expected 2.41005
# 2024-05-21 11:10:38.990563: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65537: 3.84262, expected 3.09657
# 2024-05-21 11:10:38.990575: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65538: 4.59187, expected 3.84581
# 2024-05-21 11:10:38.990586: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65539: 5.43123, expected 4.68518
# 2024-05-21 11:10:38.990599: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65540: 5.1009, expected 4.35484
# 2024-05-21 11:10:38.990610: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65541: 5.74889, expected 5.00283
# 2024-05-21 11:10:38.990621: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65542: 5.35053, expected 4.60448
# 2024-05-21 11:10:38.990634: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 65543: 5.29655, expected 4.5505
# 2024-05-21 11:10:38.997963: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[4,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,3,256,256]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-21 11:10:38.997996: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-21 11:10:38.998005: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-21 11:10:38.998013: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-21 11:10:38.998020: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-21 11:10:38.998035: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1716289907.541704      95 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.4802 - loss: 0.5198 - mean_io_u: 0.4819
# Epoch 1: val_loss improved from inf to 0.69705, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 191s 505ms/step - dice_coef: 0.4805 - loss: 0.5195 - mean_io_u: 0.4818 - val_dice_coef: 0.3029 - val_loss: 0.6971 - val_mean_io_u: 0.4291 - learning_rate: 1.0000e-04
# Epoch 2/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.5885 - loss: 0.4115 - mean_io_u: 0.5618
# Epoch 2: val_loss did not improve from 0.69705
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 478ms/step - dice_coef: 0.5885 - loss: 0.4115 - mean_io_u: 0.5616 - val_dice_coef: 0.1707 - val_loss: 0.8293 - val_mean_io_u: 0.4257 - learning_rate: 1.0000e-04
# Epoch 3/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.6286 - loss: 0.3714 - mean_io_u: 0.5863
# Epoch 3: val_loss improved from 0.69705 to 0.63322, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 97s 484ms/step - dice_coef: 0.6287 - loss: 0.3713 - mean_io_u: 0.5861 - val_dice_coef: 0.3668 - val_loss: 0.6332 - val_mean_io_u: 0.4711 - learning_rate: 1.0000e-04
# Epoch 4/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - dice_coef: 0.6621 - loss: 0.3379 - mean_io_u: 0.6115
# Epoch 4: val_loss did not improve from 0.63322
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 479ms/step - dice_coef: 0.6621 - loss: 0.3379 - mean_io_u: 0.6113 - val_dice_coef: 0.1001 - val_loss: 0.8999 - val_mean_io_u: 0.4244 - learning_rate: 1.0000e-04
# Epoch 5/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.6836 - loss: 0.3164 - mean_io_u: 0.6271
# Epoch 5: val_loss did not improve from 0.63322
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 478ms/step - dice_coef: 0.6836 - loss: 0.3164 - mean_io_u: 0.6269 - val_dice_coef: 0.1446 - val_loss: 0.8554 - val_mean_io_u: 0.4314 - learning_rate: 1.0000e-04
# Epoch 6/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.6899 - loss: 0.3101 - mean_io_u: 0.6282
# Epoch 6: val_loss did not improve from 0.63322
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 480ms/step - dice_coef: 0.6899 - loss: 0.3101 - mean_io_u: 0.6280 - val_dice_coef: 0.0856 - val_loss: 0.9144 - val_mean_io_u: 0.4284 - learning_rate: 1.0000e-04
# Epoch 7/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.7145 - loss: 0.2855 - mean_io_u: 0.6442
# Epoch 7: val_loss did not improve from 0.63322
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 478ms/step - dice_coef: 0.7145 - loss: 0.2855 - mean_io_u: 0.6440 - val_dice_coef: 0.1319 - val_loss: 0.8681 - val_mean_io_u: 0.4362 - learning_rate: 1.0000e-04
# Epoch 8/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.7244 - loss: 0.2756 - mean_io_u: 0.6478
# Epoch 8: val_loss improved from 0.63322 to 0.54561, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 97s 484ms/step - dice_coef: 0.7244 - loss: 0.2756 - mean_io_u: 0.6476 - val_dice_coef: 0.4544 - val_loss: 0.5456 - val_mean_io_u: 0.5111 - learning_rate: 1.0000e-04
# Epoch 9/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.7446 - loss: 0.2554 - mean_io_u: 0.6550
# Epoch 9: val_loss did not improve from 0.54561
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 478ms/step - dice_coef: 0.7446 - loss: 0.2554 - mean_io_u: 0.6548 - val_dice_coef: 0.2916 - val_loss: 0.7084 - val_mean_io_u: 0.4691 - learning_rate: 1.0000e-04
# Epoch 10/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.7562 - loss: 0.2438 - mean_io_u: 0.6562
# Epoch 10: val_loss did not improve from 0.54561
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 478ms/step - dice_coef: 0.7562 - loss: 0.2438 - mean_io_u: 0.6560 - val_dice_coef: 0.2453 - val_loss: 0.7547 - val_mean_io_u: 0.4586 - learning_rate: 1.0000e-04
# Epoch 11/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.7759 - loss: 0.2241 - mean_io_u: 0.6637
# Epoch 11: val_loss did not improve from 0.54561
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 478ms/step - dice_coef: 0.7759 - loss: 0.2241 - mean_io_u: 0.6635 - val_dice_coef: 0.3630 - val_loss: 0.6370 - val_mean_io_u: 0.4824 - learning_rate: 1.0000e-04
# Epoch 12/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.7786 - loss: 0.2214 - mean_io_u: 0.6653
# Epoch 12: val_loss did not improve from 0.54561
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 478ms/step - dice_coef: 0.7787 - loss: 0.2213 - mean_io_u: 0.6651 - val_dice_coef: 0.3299 - val_loss: 0.6701 - val_mean_io_u: 0.4611 - learning_rate: 1.0000e-04
# Epoch 13/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.7869 - loss: 0.2131 - mean_io_u: 0.6684
# Epoch 13: val_loss did not improve from 0.54561
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 478ms/step - dice_coef: 0.7870 - loss: 0.2130 - mean_io_u: 0.6683 - val_dice_coef: 0.1833 - val_loss: 0.8167 - val_mean_io_u: 0.4395 - learning_rate: 1.0000e-04
# Epoch 14/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.7889 - loss: 0.2111 - mean_io_u: 0.6694
# Epoch 14: val_loss improved from 0.54561 to 0.24820, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 97s 484ms/step - dice_coef: 0.7890 - loss: 0.2110 - mean_io_u: 0.6694 - val_dice_coef: 0.7518 - val_loss: 0.2482 - val_mean_io_u: 0.6728 - learning_rate: 1.0000e-05
# Epoch 15/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.8276 - loss: 0.1724 - mean_io_u: 0.6910
# Epoch 15: val_loss improved from 0.24820 to 0.24283, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 97s 484ms/step - dice_coef: 0.8276 - loss: 0.1724 - mean_io_u: 0.6909 - val_dice_coef: 0.7572 - val_loss: 0.2428 - val_mean_io_u: 0.6790 - learning_rate: 1.0000e-05
# Epoch 16/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.8357 - loss: 0.1643 - mean_io_u: 0.6893
# Epoch 16: val_loss improved from 0.24283 to 0.23696, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 97s 484ms/step - dice_coef: 0.8358 - loss: 0.1642 - mean_io_u: 0.6892 - val_dice_coef: 0.7630 - val_loss: 0.2370 - val_mean_io_u: 0.6739 - learning_rate: 1.0000e-05
# Epoch 17/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.8423 - loss: 0.1577 - mean_io_u: 0.6897
# Epoch 17: val_loss improved from 0.23696 to 0.23391, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 97s 484ms/step - dice_coef: 0.8423 - loss: 0.1577 - mean_io_u: 0.6895 - val_dice_coef: 0.7661 - val_loss: 0.2339 - val_mean_io_u: 0.6690 - learning_rate: 1.0000e-05
# Epoch 18/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.8481 - loss: 0.1519 - mean_io_u: 0.6905
# Epoch 18: val_loss improved from 0.23391 to 0.23218, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 97s 484ms/step - dice_coef: 0.8481 - loss: 0.1519 - mean_io_u: 0.6904 - val_dice_coef: 0.7678 - val_loss: 0.2322 - val_mean_io_u: 0.6635 - learning_rate: 1.0000e-05
# Epoch 19/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.8532 - loss: 0.1468 - mean_io_u: 0.6913
# Epoch 19: val_loss did not improve from 0.23218
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 478ms/step - dice_coef: 0.8532 - loss: 0.1468 - mean_io_u: 0.6912 - val_dice_coef: 0.7676 - val_loss: 0.2324 - val_mean_io_u: 0.6646 - learning_rate: 1.0000e-05
# Epoch 20/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.8580 - loss: 0.1420 - mean_io_u: 0.6926
# Epoch 20: val_loss improved from 0.23218 to 0.23197, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 97s 484ms/step - dice_coef: 0.8581 - loss: 0.1419 - mean_io_u: 0.6924 - val_dice_coef: 0.7680 - val_loss: 0.2320 - val_mean_io_u: 0.6689 - learning_rate: 1.0000e-05
# Epoch 21/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.8625 - loss: 0.1375 - mean_io_u: 0.6940
# Epoch 21: val_loss improved from 0.23197 to 0.23125, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 97s 484ms/step - dice_coef: 0.8626 - loss: 0.1374 - mean_io_u: 0.6938 - val_dice_coef: 0.7687 - val_loss: 0.2313 - val_mean_io_u: 0.6753 - learning_rate: 1.0000e-05
# Epoch 22/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.8668 - loss: 0.1332 - mean_io_u: 0.6957
# Epoch 22: val_loss improved from 0.23125 to 0.23037, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 97s 484ms/step - dice_coef: 0.8668 - loss: 0.1332 - mean_io_u: 0.6955 - val_dice_coef: 0.7696 - val_loss: 0.2304 - val_mean_io_u: 0.6751 - learning_rate: 1.0000e-05
# Epoch 23/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.8706 - loss: 0.1294 - mean_io_u: 0.6972
# Epoch 23: val_loss improved from 0.23037 to 0.23002, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 97s 484ms/step - dice_coef: 0.8706 - loss: 0.1294 - mean_io_u: 0.6970 - val_dice_coef: 0.7700 - val_loss: 0.2300 - val_mean_io_u: 0.6785 - learning_rate: 1.0000e-05
# Epoch 24/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.8745 - loss: 0.1255 - mean_io_u: 0.6987
# Epoch 24: val_loss improved from 0.23002 to 0.22987, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 97s 484ms/step - dice_coef: 0.8745 - loss: 0.1255 - mean_io_u: 0.6985 - val_dice_coef: 0.7701 - val_loss: 0.2299 - val_mean_io_u: 0.6833 - learning_rate: 1.0000e-05
# Epoch 25/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.8781 - loss: 0.1219 - mean_io_u: 0.7002
# Epoch 25: val_loss improved from 0.22987 to 0.22968, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 97s 484ms/step - dice_coef: 0.8781 - loss: 0.1219 - mean_io_u: 0.7000 - val_dice_coef: 0.7703 - val_loss: 0.2297 - val_mean_io_u: 0.6865 - learning_rate: 1.0000e-05
# Epoch 26/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.8817 - loss: 0.1183 - mean_io_u: 0.7014
# Epoch 26: val_loss improved from 0.22968 to 0.22890, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 97s 484ms/step - dice_coef: 0.8817 - loss: 0.1183 - mean_io_u: 0.7012 - val_dice_coef: 0.7711 - val_loss: 0.2289 - val_mean_io_u: 0.6841 - learning_rate: 1.0000e-05
# Epoch 27/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.8851 - loss: 0.1149 - mean_io_u: 0.7027
# Epoch 27: val_loss improved from 0.22890 to 0.22782, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 97s 484ms/step - dice_coef: 0.8852 - loss: 0.1148 - mean_io_u: 0.7026 - val_dice_coef: 0.7722 - val_loss: 0.2278 - val_mean_io_u: 0.6879 - learning_rate: 1.0000e-05
# Epoch 28/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.8883 - loss: 0.1117 - mean_io_u: 0.7042
# Epoch 28: val_loss improved from 0.22782 to 0.22755, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 97s 484ms/step - dice_coef: 0.8884 - loss: 0.1116 - mean_io_u: 0.7040 - val_dice_coef: 0.7725 - val_loss: 0.2275 - val_mean_io_u: 0.6872 - learning_rate: 1.0000e-05
# Epoch 29/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.8915 - loss: 0.1085 - mean_io_u: 0.7056
# Epoch 29: val_loss improved from 0.22755 to 0.22721, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 97s 484ms/step - dice_coef: 0.8915 - loss: 0.1085 - mean_io_u: 0.7054 - val_dice_coef: 0.7728 - val_loss: 0.2272 - val_mean_io_u: 0.6854 - learning_rate: 1.0000e-05
# Epoch 30/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.8947 - loss: 0.1053 - mean_io_u: 0.7073
# Epoch 30: val_loss improved from 0.22721 to 0.22624, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 97s 484ms/step - dice_coef: 0.8947 - loss: 0.1053 - mean_io_u: 0.7071 - val_dice_coef: 0.7738 - val_loss: 0.2262 - val_mean_io_u: 0.6861 - learning_rate: 1.0000e-05
# Epoch 31/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.8974 - loss: 0.1026 - mean_io_u: 0.7090
# Epoch 31: val_loss did not improve from 0.22624
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 478ms/step - dice_coef: 0.8975 - loss: 0.1025 - mean_io_u: 0.7089 - val_dice_coef: 0.7732 - val_loss: 0.2268 - val_mean_io_u: 0.6931 - learning_rate: 1.0000e-05
# Epoch 32/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.9001 - loss: 0.0999 - mean_io_u: 0.7112
# Epoch 32: val_loss did not improve from 0.22624
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 478ms/step - dice_coef: 0.9002 - loss: 0.0998 - mean_io_u: 0.7110 - val_dice_coef: 0.7727 - val_loss: 0.2273 - val_mean_io_u: 0.6968 - learning_rate: 1.0000e-05
# Epoch 33/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.9030 - loss: 0.0970 - mean_io_u: 0.7125
# Epoch 33: val_loss did not improve from 0.22624
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 479ms/step - dice_coef: 0.9030 - loss: 0.0970 - mean_io_u: 0.7123 - val_dice_coef: 0.7735 - val_loss: 0.2265 - val_mean_io_u: 0.6968 - learning_rate: 1.0000e-05
# Epoch 34/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.9058 - loss: 0.0942 - mean_io_u: 0.7142
# Epoch 34: val_loss did not improve from 0.22624
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 478ms/step - dice_coef: 0.9058 - loss: 0.0942 - mean_io_u: 0.7141 - val_dice_coef: 0.7699 - val_loss: 0.2301 - val_mean_io_u: 0.7045 - learning_rate: 1.0000e-05
# Epoch 35/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.9085 - loss: 0.0915 - mean_io_u: 0.7163
# Epoch 35: val_loss improved from 0.22624 to 0.22439, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 97s 484ms/step - dice_coef: 0.9086 - loss: 0.0914 - mean_io_u: 0.7161 - val_dice_coef: 0.7756 - val_loss: 0.2244 - val_mean_io_u: 0.6973 - learning_rate: 1.0000e-05
# Epoch 36/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.9112 - loss: 0.0888 - mean_io_u: 0.7184
# Epoch 36: val_loss did not improve from 0.22439
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 478ms/step - dice_coef: 0.9112 - loss: 0.0888 - mean_io_u: 0.7182 - val_dice_coef: 0.7695 - val_loss: 0.2305 - val_mean_io_u: 0.7076 - learning_rate: 1.0000e-05
# Epoch 37/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.9139 - loss: 0.0861 - mean_io_u: 0.7195
# Epoch 37: val_loss did not improve from 0.22439
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 478ms/step - dice_coef: 0.9139 - loss: 0.0861 - mean_io_u: 0.7194 - val_dice_coef: 0.7706 - val_loss: 0.2294 - val_mean_io_u: 0.7072 - learning_rate: 1.0000e-05
# Epoch 38/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.9166 - loss: 0.0834 - mean_io_u: 0.7222
# Epoch 38: val_loss did not improve from 0.22439
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 478ms/step - dice_coef: 0.9167 - loss: 0.0833 - mean_io_u: 0.7221 - val_dice_coef: 0.7688 - val_loss: 0.2312 - val_mean_io_u: 0.7113 - learning_rate: 1.0000e-05
# Epoch 39/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - dice_coef: 0.9196 - loss: 0.0804 - mean_io_u: 0.7240
# Epoch 39: val_loss did not improve from 0.22439
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 142s 478ms/step - dice_coef: 0.9196 - loss: 0.0804 - mean_io_u: 0.7239 - val_dice_coef: 0.7697 - val_loss: 0.2303 - val_mean_io_u: 0.7120 - learning_rate: 1.0000e-05
# Epoch 40/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.9221 - loss: 0.0779 - mean_io_u: 0.7259
# Epoch 40: val_loss did not improve from 0.22439
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 479ms/step - dice_coef: 0.9221 - loss: 0.0779 - mean_io_u: 0.7258 - val_dice_coef: 0.7665 - val_loss: 0.2335 - val_mean_io_u: 0.7183 - learning_rate: 1.0000e-05
# Epoch 41/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.9216 - loss: 0.0784 - mean_io_u: 0.7323
# Epoch 41: val_loss improved from 0.22439 to 0.21948, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 97s 484ms/step - dice_coef: 0.9216 - loss: 0.0784 - mean_io_u: 0.7322 - val_dice_coef: 0.7805 - val_loss: 0.2195 - val_mean_io_u: 0.6822 - learning_rate: 1.0000e-06
# Epoch 42/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.9240 - loss: 0.0760 - mean_io_u: 0.7325
# Epoch 42: val_loss improved from 0.21948 to 0.21908, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 97s 484ms/step - dice_coef: 0.9240 - loss: 0.0760 - mean_io_u: 0.7324 - val_dice_coef: 0.7809 - val_loss: 0.2191 - val_mean_io_u: 0.6832 - learning_rate: 1.0000e-06
# Epoch 43/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.9249 - loss: 0.0751 - mean_io_u: 0.7323
# Epoch 43: val_loss improved from 0.21908 to 0.21902, saving model to files/model.keras
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 97s 484ms/step - dice_coef: 0.9249 - loss: 0.0751 - mean_io_u: 0.7321 - val_dice_coef: 0.7810 - val_loss: 0.2190 - val_mean_io_u: 0.6838 - learning_rate: 1.0000e-06
# Epoch 44/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.9256 - loss: 0.0744 - mean_io_u: 0.7322
# Epoch 44: val_loss did not improve from 0.21902
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 479ms/step - dice_coef: 0.9256 - loss: 0.0744 - mean_io_u: 0.7320 - val_dice_coef: 0.7809 - val_loss: 0.2191 - val_mean_io_u: 0.6843 - learning_rate: 1.0000e-06
# Epoch 45/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.9261 - loss: 0.0739 - mean_io_u: 0.7321
# Epoch 45: val_loss did not improve from 0.21902
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 478ms/step - dice_coef: 0.9261 - loss: 0.0739 - mean_io_u: 0.7320 - val_dice_coef: 0.7808 - val_loss: 0.2192 - val_mean_io_u: 0.6849 - learning_rate: 1.0000e-06
# Epoch 46/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.9266 - loss: 0.0734 - mean_io_u: 0.7322
# Epoch 46: val_loss did not improve from 0.21902
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 478ms/step - dice_coef: 0.9266 - loss: 0.0734 - mean_io_u: 0.7320 - val_dice_coef: 0.7808 - val_loss: 0.2192 - val_mean_io_u: 0.6852 - learning_rate: 1.0000e-06
# Epoch 47/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.9271 - loss: 0.0729 - mean_io_u: 0.7323
# Epoch 47: val_loss did not improve from 0.21902
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 478ms/step - dice_coef: 0.9271 - loss: 0.0729 - mean_io_u: 0.7322 - val_dice_coef: 0.7807 - val_loss: 0.2193 - val_mean_io_u: 0.6856 - learning_rate: 1.0000e-06
# Epoch 48/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.9275 - loss: 0.0725 - mean_io_u: 0.7324
# Epoch 48: val_loss did not improve from 0.21902
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 478ms/step - dice_coef: 0.9276 - loss: 0.0724 - mean_io_u: 0.7323 - val_dice_coef: 0.7799 - val_loss: 0.2201 - val_mean_io_u: 0.6887 - learning_rate: 1.0000e-07
# Epoch 49/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - dice_coef: 0.9277 - loss: 0.0723 - mean_io_u: 0.7328
# Epoch 49: val_loss did not improve from 0.21902
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 479ms/step - dice_coef: 0.9277 - loss: 0.0723 - mean_io_u: 0.7327 - val_dice_coef: 0.7797 - val_loss: 0.2203 - val_mean_io_u: 0.6888 - learning_rate: 1.0000e-07
# Epoch 50/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.9278 - loss: 0.0722 - mean_io_u: 0.7331
# Epoch 50: val_loss did not improve from 0.21902
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 142s 479ms/step - dice_coef: 0.9278 - loss: 0.0722 - mean_io_u: 0.7329 - val_dice_coef: 0.7797 - val_loss: 0.2203 - val_mean_io_u: 0.6886 - learning_rate: 1.0000e-07
# Epoch 51/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - dice_coef: 0.9279 - loss: 0.0721 - mean_io_u: 0.7331
# Epoch 51: val_loss did not improve from 0.21902
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 479ms/step - dice_coef: 0.9279 - loss: 0.0721 - mean_io_u: 0.7330 - val_dice_coef: 0.7797 - val_loss: 0.2203 - val_mean_io_u: 0.6885 - learning_rate: 1.0000e-07
# Epoch 52/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - dice_coef: 0.9280 - loss: 0.0720 - mean_io_u: 0.7332
# Epoch 52: val_loss did not improve from 0.21902
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 479ms/step - dice_coef: 0.9280 - loss: 0.0720 - mean_io_u: 0.7331 - val_dice_coef: 0.7797 - val_loss: 0.2203 - val_mean_io_u: 0.6884 - learning_rate: 1.0000e-07
# Epoch 53/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - dice_coef: 0.9281 - loss: 0.0719 - mean_io_u: 0.7331
# Epoch 53: val_loss did not improve from 0.21902
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 96s 479ms/step - dice_coef: 0.9281 - loss: 0.0719 - mean_io_u: 0.7330 - val_dice_coef: 0.7796 - val_loss: 0.2204 - val_mean_io_u: 0.6889 - learning_rate: 1.0000e-08

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import numpy as np
import cv2
import imageio
from glob import glob
from tqdm import tqdm
import tensorflow as tf
# from train import create_dir, load_dataset
# from metrics import dice_loss, dice_coef

IMG_H = 256
IMG_W = 256

if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir(f"results")

    """ Load the model """
    model_path = os.path.join("files", "model.keras")
    model = tf.keras.models.load_model(model_path, custom_objects={"dice_loss": dice_loss, "dice_coef": dice_coef})

    """ Dataset """
    dataset_path = "/kaggle/input/kvasir-seg/Kvasir-SEG"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_dataset(dataset_path)

    print(f"Train: \t{len(train_x)} - {len(train_y)}")
    print(f"Valid: \t{len(valid_x)} - {len(valid_y)}")
    print(f"Test: \t{len(test_x)} - {len(test_y)}")

    """ Prediction """
    for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
        """ Extracting the name """
        name = x.split("/")[-1].split(".")[0]

        """ Reading the image """
        image = cv2.imread(x, cv2.IMREAD_COLOR)
        image = cv2.resize(image, (IMG_W, IMG_H))
        x = image / 255.0
        x = np.expand_dims(x, axis=0)

        """ Read Mask """
        mask = cv2.imread(y, cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, (IMG_W, IMG_H))
        mask = mask / 255.0
        mask = np.expand_dims(mask, axis=-1)
        mask = np.concatenate([mask, mask, mask], axis=-1)

        """ Prediction """
        pred = model.predict(x, verbose=0)[0]
        pred = np.concatenate([pred, pred, pred], axis=-1)
        # pred = (pred > 0.5).astype(np.int32)

        """ Save final mask """
        line = np.ones((IMG_H, 10, 3)) * 255
        cat_images = np.concatenate([image, line, mask*255, line, pred*255], axis=1)
        save_image_path = os.path.join("results",  f"{name}.jpg")
        cv2.imwrite(save_image_path, cat_images)
# Out:
# Train: 	800 - 800
# Valid: 	100 - 100
# Test: 	100 - 100
#   0%|          | 0/100 [00:00<?, ?it/s]2024-05-21 12:39:18.995871: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 2.86272, expected 2.0465
# 2024-05-21 12:39:18.995941: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 4.04967, expected 3.23345
# 2024-05-21 12:39:18.995950: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 4.4326, expected 3.61638
# 2024-05-21 12:39:18.995958: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 5.46868, expected 4.65247
# 2024-05-21 12:39:18.995966: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 5.37814, expected 4.56193
# 2024-05-21 12:39:18.995974: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 5.18374, expected 4.36753
# 2024-05-21 12:39:18.995982: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 5.54872, expected 4.7325
# 2024-05-21 12:39:18.995989: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 5.78654, expected 4.97032
# 2024-05-21 12:39:18.995996: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 4.0901, expected 3.27388
# 2024-05-21 12:39:18.996004: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 5.11265, expected 4.29643
# 2024-05-21 12:39:18.998347: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[1,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,3,256,256]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-21 12:39:18.998377: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-21 12:39:18.998391: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-21 12:39:18.998401: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-21 12:39:18.998410: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-21 12:39:18.998428: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-05-21 12:39:19.063561: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 2.86272, expected 2.0465
# 2024-05-21 12:39:19.063604: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 1: 4.04967, expected 3.23345
# 2024-05-21 12:39:19.063617: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 2: 4.4326, expected 3.61638
# 2024-05-21 12:39:19.063630: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 3: 5.46868, expected 4.65247
# 2024-05-21 12:39:19.063648: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 4: 5.37814, expected 4.56193
# 2024-05-21 12:39:19.063661: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 5: 5.18374, expected 4.36753
# 2024-05-21 12:39:19.063671: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 6: 5.54872, expected 4.7325
# 2024-05-21 12:39:19.063684: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 7: 5.78654, expected 4.97032
# 2024-05-21 12:39:19.063697: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 8: 4.0901, expected 3.27388
# 2024-05-21 12:39:19.063710: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 9: 5.11265, expected 4.29643
# 2024-05-21 12:39:19.065560: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[1,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,3,256,256]{3,2,1,0}, f32[64,3,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=1,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-21 12:39:19.065589: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-21 12:39:19.065601: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-21 12:39:19.065615: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-21 12:39:19.065629: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-21 12:39:19.065646: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 100%|██████████| 100/100 [00:22<00:00,  4.39it/s]

# %%
test_dataset = tf_dataset(test_x, test_y, batch=batch_size)

# %%
results = model.evaluate(test_dataset)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 189ms/step - dice_coef: 0.7928 - loss: 0.2072 - mean_io_u: 0.7051

# %%
# !zip -r file.zip /kaggle/working
# Out:
#   adding: kaggle/working/ (stored 0%)
#   adding: kaggle/working/.virtual_documents/ (stored 0%)
#   adding: kaggle/working/results/ (stored 0%)
#   adding: kaggle/working/results/cju7ev2b12owa08500bpfpwyw.jpg (deflated 7%)
#   adding: kaggle/working/results/cju1g4nsb6ngy0799l4ezm8ab.jpg (deflated 8%)
#   adding: kaggle/working/results/cju2qozsk20cq0855ugrg3cri.jpg (deflated 6%)
#   adding: kaggle/working/results/cju6vta3kvazg0817qbeppjtm.jpg (deflated 6%)
#   adding: kaggle/working/results/cju0vtox5ain6099360pu62rp.jpg (deflated 13%)
#   adding: kaggle/working/results/cju2wx0gh7fpz0878wwyd9ep8.jpg (deflated 9%)
#   adding: kaggle/working/results/cju7d2q1k27nf08715zshsckt.jpg (deflated 9%)
#   adding: kaggle/working/results/cju8bm24yrrdp081829mbo8ic.jpg (deflated 9%)
#   adding: kaggle/working/results/cju7dsrtb2f8i085064kwugfk.jpg (deflated 11%)
#   adding: kaggle/working/results/cju1fuoa4wmc50835qfd11sp9.jpg (deflated 11%)
#   adding: kaggle/working/results/cju87tyddnnad0755bj0wxahe.jpg (deflated 6%)
#   adding: kaggle/working/results/cju88q6h6obpd0871ckmiabbo.jpg (deflated 9%)
#   adding: kaggle/working/results/cju1hirfi7ekp0855q0vgm9qq.jpg (deflated 8%)
#   adding: kaggle/working/results/cju1ejj7dvqfa0835ra184v5m.jpg (deflated 8%)
#   adding: kaggle/working/results/cju42qet0lsq90871e50xbnuv.jpg (deflated 10%)
#   adding: kaggle/working/results/cju7et17a2vjk0755e743npl1.jpg (deflated 10%)
#   adding: kaggle/working/results/cju40m0rjkpw80871z6n6yg1u.jpg (deflated 7%)
#   adding: kaggle/working/results/cju88cddensj00987788yotmg.jpg (deflated 10%)
#   adding: kaggle/working/results/cju5huurrecm70801y680y13m.jpg (deflated 10%)
#   adding: kaggle/working/results/cju3x2s11ibzi0817kk284k0j.jpg (deflated 9%)
#   adding: kaggle/working/results/cju5eq8c8ck690850vix98hv3.jpg (deflated 7%)
#   adding: kaggle/working/results/cju30525w04r10835ygp257sb.jpg (deflated 9%)
#   adding: kaggle/working/results/cju3uz4o6gr9z0850lhxyxvsj.jpg (deflated 9%)
#   adding: kaggle/working/results/cju2xf8e5y2wm08359vcgk09b.jpg (deflated 8%)
#   adding: kaggle/working/results/cju2tjrog4jy30878pawyazqc.jpg (deflated 10%)
#   adding: kaggle/working/results/cju6vqarjv7yo0987q4b1btk1.jpg (deflated 10%)
#   adding: kaggle/working/results/cju5wkonqlrl409877y8zvnub.jpg (deflated 8%)
#   adding: kaggle/working/results/cju7cue9b232j0801qdzk1ykj.jpg (deflated 11%)
#   adding: kaggle/working/results/cju34fojcctcf0799ebolbvkn.jpg (deflated 12%)
#   adding: kaggle/working/results/cju302fqq9spc0878rrygyzzz.jpg (deflated 6%)
#   adding: kaggle/working/results/cju40sdwukv3k0755y99ug1k8.jpg (deflated 6%)
#   adding: kaggle/working/results/cju1c8ffau5770835g0g343o8.jpg (deflated 7%)
#   adding: kaggle/working/results/cju183od81ff608017ekzif89.jpg (deflated 8%)
#   adding: kaggle/working/results/cju1csmlc4ht10799b8ymmghg.jpg (deflated 10%)
#   adding: kaggle/working/results/cju5fs6j6d8350801vglraq4u.jpg (deflated 7%)
#   adding: kaggle/working/results/cju7dymur2od30755eg8yv2ht.jpg (deflated 10%)
#   adding: kaggle/working/results/cju84dsvaklpx098750hp83x4.jpg (deflated 7%)
#   adding: kaggle/working/results/cju1euuc65wm00799m4sjdnnn.jpg (deflated 9%)
#   adding: kaggle/working/results/cju7dvl5m2n4t0755hlnnjjet.jpg (deflated 9%)
#   adding: kaggle/working/results/cju8alhigqn2h0801zksudldd.jpg (deflated 7%)
#   adding: kaggle/working/results/cju5h57xedz5h0755mjpc8694.jpg (deflated 5%)
#   adding: kaggle/working/results/cju2zrojo9kcd0878ld2epejq.jpg (deflated 11%)
#   adding: kaggle/working/results/cju8418jhkf7d0818ga2v0xq0.jpg (deflated 7%)
#   adding: kaggle/working/results/cju0sxqiclckk08551ycbwhno.jpg (deflated 11%)
#   adding: kaggle/working/results/cju41kd7yl4nm0850gil5qqwh.jpg (deflated 11%)
#   adding: kaggle/working/results/cju6xlygpw7bs0818n691jsq4.jpg (deflated 8%)
#   adding: kaggle/working/results/cju43gfosm63n08714rpih8pe.jpg (deflated 8%)
#   adding: kaggle/working/results/cju0sr5ghl0nd08789uzf1raf.jpg (deflated 6%)
#   adding: kaggle/working/results/cju42u5bjlvi10801dc13sskp.jpg (deflated 10%)
#   adding: kaggle/working/results/cju8a84g0q76m0818hwiggkod.jpg (deflated 6%)
#   adding: kaggle/working/results/cju2rn0hasxri0835nfy3buay.jpg (deflated 10%)
#   adding: kaggle/working/results/cju2wxv0hxs2f09884w48v8fi.jpg (deflated 9%)
#   adding: kaggle/working/results/cju7agj961l2r0818z29iq8yn.jpg (deflated 12%)
#   adding: kaggle/working/results/cju7db7lp2f400755tntd1ohf.jpg (deflated 8%)
#   adding: kaggle/working/results/cju1b75x63ddl0799sdp0i2j3.jpg (deflated 11%)
#   adding: kaggle/working/results/cju7b3f5h1sm40755i572jden.jpg (deflated 8%)
#   adding: kaggle/working/results/cju3u4lxmg59o0755rz42b9en.jpg (deflated 8%)
#   adding: kaggle/working/results/cju41p90plcsx08018cnzpndc.jpg (deflated 8%)
#   adding: kaggle/working/results/cju8cj10qsrau0871o2dr6ai1.jpg (deflated 11%)
#   adding: kaggle/working/results/cju7efffp2ivf0817etg3jehl.jpg (deflated 7%)
#   adding: kaggle/working/results/cju5wqonpm0e60801z88ewmy1.jpg (deflated 8%)
#   adding: kaggle/working/results/cju85hguellg50818kwu3s8d1.jpg (deflated 6%)
#   adding: kaggle/working/results/cju326h4v1gxw08352px40p7r.jpg (deflated 6%)
#   adding: kaggle/working/results/cju83syhdk6gs0801rf1rekdl.jpg (deflated 7%)
#   adding: kaggle/working/results/cju8cwy02t9eq08185qn12c02.jpg (deflated 9%)
#   adding: kaggle/working/results/cju2oq5570avm079959o20op1.jpg (deflated 9%)
#   adding: kaggle/working/results/cju88l66no10s0850rsda7ej1.jpg (deflated 6%)
#   adding: kaggle/working/results/cju8bljw9rqk20801kr54akrl.jpg (deflated 7%)
#   adding: kaggle/working/results/cju87z6o6nh73085045bzsx6o.jpg (deflated 11%)
#   adding: kaggle/working/results/cju83h9ysjwe808716nt35oah.jpg (deflated 11%)
#   adding: kaggle/working/results/cju35fxqyzt5p0993vusm54qz.jpg (deflated 9%)
#   adding: kaggle/working/results/cju8402x1kcy70801t6kz6bdi.jpg (deflated 7%)
#   adding: kaggle/working/results/cju5fb86jd1jp0755b1ukbhq5.jpg (deflated 8%)
#   adding: kaggle/working/results/cjyzkmjy8evns070165gf9dmq.jpg (deflated 9%)
#   adding: kaggle/working/results/cju7bmi1v1pnj0987pa52jjok.jpg (deflated 9%)
#   adding: kaggle/working/results/cju2txjfzv60w098839dcimys.jpg (deflated 12%)
#   adding: kaggle/working/results/cju1hyolc7aqu0878rrkfn1lr.jpg (deflated 10%)
#   adding: kaggle/working/results/cju3tp94kfstl08181awh6z49.jpg (deflated 6%)
#   adding: kaggle/working/results/cju33za6l2qy70988jhrlp2ev.jpg (deflated 9%)
#   adding: kaggle/working/results/cju89z6pqpqfx0817mfv8ixjc.jpg (deflated 13%)
#   adding: kaggle/working/results/cju83wwn1k55e0850kw6i2d81.jpg (deflated 7%)
#   adding: kaggle/working/results/cju87zv8lni0o0850hbbecbq6.jpg (deflated 7%)
#   adding: kaggle/working/results/cju15wdt3zla10801odjiw7sy.jpg (deflated 8%)
#   adding: kaggle/working/results/cju6wi3akvn8r0801px8eligc.jpg (deflated 6%)
#   adding: kaggle/working/results/cju5u6wf0kh1t0755bg1ssixv.jpg (deflated 6%)
#   adding: kaggle/working/results/cju5xopi0md7q0871r1sjc1av.jpg (deflated 9%)
#   adding: kaggle/working/results/cju1aqqv02qwz0878a5cyhr67.jpg (deflated 9%)
#   adding: kaggle/working/results/cju5wuhm1lwm40987vugqn3vv.jpg (deflated 9%)
#   adding: kaggle/working/results/ck2bxskgxxzfv08386xkqtqdy.jpg (deflated 11%)
#   adding: kaggle/working/results/cju30gxjq0djk0988jytm49rs.jpg (deflated 9%)
#   adding: kaggle/working/results/cju1cfhyg48bb0799cl5pr2jh.jpg (deflated 7%)
#   adding: kaggle/working/results/cju17g6ykn1cs0993dww6qdi8.jpg (deflated 6%)
#   adding: kaggle/working/results/cju7dizi82h2i0755doucgnt3.jpg (deflated 8%)
#   adding: kaggle/working/results/cju5ca9hcatkc0801jzwe7tfx.jpg (deflated 6%)
#   adding: kaggle/working/results/cju439oazm2fu0871ma0vvrft.jpg (deflated 7%)
#   adding: kaggle/working/results/cju87kbcen2av0987usezo8kn.jpg (deflated 8%)
#   adding: kaggle/working/results/cju33mirdc8mj0799k33wzoes.jpg (deflated 7%)
#   adding: kaggle/working/results/cju85ia1slh220987y7c20sm2.jpg (deflated 9%)
#   adding: kaggle/working/results/cju3xiic0ilzp0850lusrb42j.jpg (deflated 14%)
#   adding: kaggle/working/results/cju3v11mrgwwb0755u242ygye.jpg (deflated 10%)
#   adding: kaggle/working/files/ (stored 0%)
#   adding: kaggle/working/files/model.keras (deflated 7%)
#   adding: kaggle/working/files/log.csv (deflated 57%)
